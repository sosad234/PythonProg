# %%
import pandas as pd
import wikipedia as wp
html = wp.page("List_of_video_games_considered_the_best").html().encode("UTF-8")
try: 
    df = pd.read_html(html)[1]  # Try 2nd table first as most pages contain contents table first
except IndexError:
    df = pd.read_html(html)[0]
print(df.to_string())
# Out:
#      Year                                                Game                     Genre                        Publisher                  Original platform(s)[a]  Ref.
# 0    1971                                    The Oregon Trail                  Strategy                             MECC                                  HP 2100   [A]
# 1    1972                                                Pong                    Sports                      Atari, Inc.                                   Arcade   [B]
# 2    1977                                              Combat          Top-down shooter                      Atari, Inc.                               Atari 2600   [C]
# 3    1977                                                Zork                 Adventure                          Infocom                                   PDP-10   [D]
# 4    1978                                      Space Invaders              Shoot 'em up                            Taito                                   Arcade   [E]
# 5    1979                                           Asteroids              Shoot 'em up                      Atari, Inc.                                   Arcade   [F]
# 6    1980                                           Adventure          Action-adventure                      Atari, Inc.                               Atari 2600   [G]
# 7    1980                                          Battlezone        Vehicle simulation                      Atari, Inc.                                   Arcade   [H]
# 8    1980                                     Missile Command              Shoot 'em up                      Atari, Inc.                                   Arcade   [I]
# 9    1980                                             Pac-Man                      Maze                            Namco                                   Arcade   [J]
# 10   1981                                           Centipede              Shoot 'em up                      Atari, Inc.                                   Arcade   [K]
# 11   1981                                            Defender              Shoot 'em up             Williams Electronics                                   Arcade   [L]
# 12   1981                                         Donkey Kong                  Platform                         Nintendo                                   Arcade   [M]
# 13   1981                                             Frogger                    Action                     Konami, Sega                                   Arcade   [N]
# 14   1981                                              Galaga              Shoot 'em up                            Namco                                   Arcade   [O]
# 15   1981                                             Tempest              Shoot 'em up                      Atari, Inc.                                   Arcade   [P]
# 16   1981       Wizardry: Proving Grounds of the Mad Overlord              Role-playing                         Sir-Tech                                 Apple II   [Q]
# 17   1982                                               Joust                    Action             Williams Electronics                                   Arcade   [R]
# 18   1982                                         Ms. Pac-Man                      Maze                           Midway                                   Arcade   [S]
# 19   1982                                            Pitfall!                  Platform                       Activision                               Atari 2600   [T]
# 20   1982                                      Robotron: 2084          Top-down shooter             Williams Electronics                                   Arcade   [U]
# 21   1983                      Archon: The Light and the Dark                  Strategy                  Electronic Arts                       Atari 8-bit family   [V]
# 22   1983                                         Lode Runner                  Platform                       Broderbund                                 Apple II   [W]
# 23   1983                                            M.U.L.E.       Business simulation                  Electronic Arts                       Atari 8-bit family   [X]
# 24   1983                                           Star Wars              Rail shooter                      Atari, Inc.                                   Arcade   [Y]
# 25   1984                                               Elite    Space flight simulator                        Acornsoft                                BBC Micro   [Z]
# 26   1984                                      Marble Madness                    Action                      Atari Games                                   Arcade  [AA]
# 27   1985                                            Gauntlet            Hack and slash                      Atari Games                                   Arcade  [AB]
# 28   1985                                   Ghosts 'n Goblins                  Platform                           Capcom                                   Arcade  [AC]
# 29   1985                                   Super Mario Bros.                  Platform                         Nintendo                                      NES  [AD]
# 30   1985                                              Tetris                    Puzzle                            Elorg                           Electronika 60  [AE]
# 31   1985                      Ultima IV: Quest of the Avatar              Role-playing                   Origin Systems                                 Apple II  [AF]
# 32   1986                                            Arkanoid             Block breaker                            Taito                                   Arcade  [AG]
# 33   1986                                       Bubble Bobble                  Platform                            Taito                                   Arcade  [AH]
# 34   1986                                 The Legend of Zelda          Action-adventure                         Nintendo                                      NES  [AI]
# 35   1986                                             Out Run                    Racing                             Sega                                   Arcade  [AJ]
# 36   1987                                              Contra               Run and gun                           Konami                                   Arcade  [AK]
# 37   1987                                       Double Dragon               Beat 'em up                    Technos Japan                                   Arcade  [AL]
# 38   1987                                      Dungeon Master              Role-playing                        FTL Games                                 Atari ST  [AM]
# 39   1987                            Mike Tyson's Punch-Out!!                    Sports                         Nintendo                                      NES  [AN]
# 40   1987                                              R-Type              Shoot 'em up                             Irem                                   Arcade  [AO]
# 41   1987                                Sid Meier's Pirates!          Action-adventure                       MicroProse                             Commodore 64  [AP]
# 42   1988                                          Mega Man 2                  Platform                           Capcom                                      NES  [AQ]
# 43   1988                                        Ninja Gaiden                  Platform                            Tecmo                                      NES  [AR]
# 44   1988                                 Super Mario Bros. 3                  Platform                         Nintendo                                      NES  [AS]
# 45   1989                                         Final Fight               Beat 'em up                           Capcom                                   Arcade  [AT]
# 46   1989                                            Populous                  God game                  Electronic Arts                                    Amiga  [AU]
# 47   1989                                    Prince of Persia                  Platform                       Broderbund                                 Apple II  [AV]
# 48   1989                                             SimCity             City-building                            Maxis                               Amiga, Mac  [AW]
# 49   1990                         The Secret of Monkey Island                 Adventure                        LucasArts                                       PC  [AX]
# 50   1990                          Speedball 2: Brutal Deluxe                    Sports                      Image Works                          Amiga, Atari ST  [AY]
# 51   1990                                   Super Mario World                  Platform                         Nintendo                                Super NES  [AZ]
# 52   1990                                      Wing Commander    Space flight simulator                   Origin Systems                                       PC  [BA]
# 53   1991                                       Another World                  Platform                Delphine Software                          Amiga, Atari ST  [BB]
# 54   1991                                        Civilization       Turn-based strategy                       MicroProse                                       PC  [BC]
# 55   1991                                    Final Fantasy IV              Role-playing                           Square                                Super NES  [BD]
# 56   1991             The Legend of Zelda: A Link to the Past          Action-adventure                         Nintendo                                Super NES  [BE]
# 57   1991                                            Lemmings                    Puzzle                        Psygnosis                                    Amiga  [BF]
# 58   1991                                      Micro Machines                    Racing                         Camerica                                      NES  [BG]
# 59   1991                  Monkey Island 2: LeChuck's Revenge                 Adventure                        LucasArts                                       PC  [BH]
# 60   1991                                  Sonic the Hedgehog                  Platform                             Sega                             Sega Genesis  [BI]
# 61   1991                                   Street Fighter II                  Fighting                           Capcom                                   Arcade  [BJ]
# 62   1991                                Super Castlevania IV                  Platform                           Konami                                Super NES  [BK]
# 63   1992                                   Alone in the Dark           Survival horror                       Infogrames                                       PC  [BL]
# 64   1992                          Contra III: The Alien Wars               Run and gun                           Konami                                Super NES  [BM]
# 65   1992                                             Dune II        Real-time strategy                     Virgin Games                                       PC  [BN]
# 66   1992                                           Flashback                  Platform                        U.S. Gold                                    Amiga  [BO]
# 67   1992              Indiana Jones and the Fate of Atlantis                 Adventure                        LucasArts                                       PC  [BP]
# 68   1992                                       Mortal Kombat                  Fighting                           Midway                                   Arcade  [BQ]
# 69   1992                                     Sensible Soccer                    Sports                Renegade Software                          Amiga, Atari ST  [BR]
# 70   1992                                Sonic the Hedgehog 2                  Platform                             Sega                             Sega Genesis  [BS]
# 71   1992                                     Star Control II          Action-adventure                         Accolade                                       PC  [BT]
# 72   1992                                   Streets of Rage 2               Beat 'em up                             Sega                             Sega Genesis  [BU]
# 73   1992                                    Super Mario Kart               Kart racing                         Nintendo                                Super NES  [BV]
# 74   1992                          Ultima VII: The Black Gate              Role-playing                   Origin Systems                                       PC  [BW]
# 75   1992                                       Virtua Racing                    Racing                             Sega                                   Arcade  [BX]
# 76   1992                                      Wolfenstein 3D      First-person shooter                  Apogee Software                                       PC  [BY]
# 77   1993                                 Day of the Tentacle                 Adventure                        LucasArts                                       PC  [BZ]
# 78   1993                                                Doom      First-person shooter                      id Software                                       PC  [CA]
# 79   1993                                      Gunstar Heroes               Run and gun                             Sega                             Sega Genesis  [CB]
# 80   1993               The Legend of Zelda: Link's Awakening          Action-adventure                         Nintendo                                 Game Boy  [CC]
# 81   1993                                          Mega Man X                  Platform                           Capcom                                Super NES  [CD]
# 82   1993                                    Mortal Kombat II                  Fighting                           Midway                                   Arcade  [CE]
# 83   1993                                                Myst                 Adventure                       Broderbund                                      Mac  [CF]
# 84   1993                                             NBA Jam                    Sports                           Midway                                   Arcade  [CG]
# 85   1993                                    Phantasy Star IV              Role-playing                             Sega                             Sega Genesis  [CH]
# 86   1993                                         Ridge Racer                    Racing                            Namco                                   Arcade  [CI]
# 87   1993                              Sam & Max Hit the Road                 Adventure                        LucasArts                                       PC  [CJ]
# 88   1993                                      Secret of Mana       Action role-playing                           Square                                Super NES  [CK]
# 89   1993                                     Samurai Shodown                  Fighting                              SNK                                   Arcade  [CL]
# 90   1993                                        SimCity 2000             City-building                            Maxis                                      Mac  [CM]
# 91   1993                                            Star Fox              Rail shooter                         Nintendo                                Super NES  [CN]
# 92   1993                                           Syndicate         Real-time tactics                  Electronic Arts                                Amiga, PC  [CO]
# 93   1994                                         Daytona USA                    Racing                             Sega                                   Arcade  [CP]
# 94   1994                                 Donkey Kong Country                  Platform                         Nintendo                                Super NES  [CQ]
# 95   1994                                             Doom II      First-person shooter                   GT Interactive                                       PC  [CR]
# 96   1994                                          EarthBound              Role-playing                         Nintendo                                Super NES  [CS]
# 97   1994                                    Final Fantasy VI              Role-playing                           Square                                Super NES  [CT]
# 98   1994                             Sega Rally Championship                    Racing                             Sega                                   Arcade  [CU]
# 99   1994                            Sensible World of Soccer                    Sports                Renegade Software                                    Amiga  [CV]
# 100  1994                              Star Wars: TIE Fighter    Space flight simulator                        LucasArts                                       PC  [CW]
# 101  1994                                       Super Metroid          Action-adventure                         Nintendo                                Super NES  [CX]
# 102  1994                                        Tempest 2000              Shoot 'em up                Atari Corporation                             Atari Jaguar  [CY]
# 103  1994                                          Theme Park       Business simulation                  Electronic Arts                                Amiga, PC  [CZ]
# 104  1994                                    Virtua Fighter 2                  Fighting                             Sega                                   Arcade  [DA]
# 105  1994                                  X-COM: UFO Defense       Turn-based strategy                       MicroProse                                       PC  [DB]
# 106  1995                                      Chrono Trigger              Role-playing                           Square                                Super NES  [DC]
# 107  1995                                   Command & Conquer        Real-time strategy               Virgin Interactive                                       PC  [DD]
# 108  1995                  MechWarrior 2: 31st Century Combat        Vehicle simulation                       Activision                                       PC  [DE]
# 109  1995                      Warcraft II: Tides of Darkness        Real-time strategy           Blizzard Entertainment                                       PC  [DF]
# 110  1995                                             Wipeout                    Racing                        Psygnosis                          PC, PlayStation  [DG]
# 111  1995                                               Worms                 Artillery                   Ocean Software                                    Amiga  [DH]
# 112  1995                                      Yoshi's Island                  Platform                         Nintendo                                Super NES  [DI]
# 113  1996                                     Civilization II       Turn-based strategy                       MicroProse                                       PC  [DJ]
# 114  1996                        Command & Conquer: Red Alert        Real-time strategy               Virgin Interactive                                       PC  [DK]
# 115  1996                                       Duke Nukem 3D      First-person shooter                   GT Interactive                                       PC  [DL]
# 116  1996                                       Mario Kart 64               Kart racing                         Nintendo                              Nintendo 64  [DM]
# 117  1996                                  Nights into Dreams                    Action                             Sega                                   Saturn  [DN]
# 118  1996                                  PaRappa the Rapper                    Rhythm      Sony Computer Entertainment                              PlayStation  [DO]
# 119  1996                               PokÃ©mon Red and Blue              Role-playing                         Nintendo                                 Game Boy  [DP]
# 120  1996                                               Quake      First-person shooter                   GT Interactive                                       PC  [DQ]
# 121  1996                                       Resident Evil           Survival horror                           Capcom                              PlayStation  [DR]
# 122  1996                                      Super Mario 64                  Platform                         Nintendo                              Nintendo 64  [DS]
# 123  1996                                         Tomb Raider          Action-adventure                Eidos Interactive                  Saturn, PC, PlayStation  [DT]
# 124  1996                                        Wave Race 64                    Racing                         Nintendo                              Nintendo 64  [DU]
# 125  1996                                        Wipeout 2097                    Racing                        Psygnosis                              PlayStation  [DV]
# 126  1997                                      Age of Empires        Real-time strategy                        Microsoft                                       PC  [DW]
# 127  1997                  Castlevania: Symphony of the Night          Action-adventure                           Konami                              PlayStation  [DX]
# 128  1997                                              Diablo       Action role-playing           Blizzard Entertainment                                       PC  [DY]
# 129  1997                                             Fallout              Role-playing          Interplay Entertainment                                       PC  [DZ]
# 130  1997                               Final Fantasy Tactics     Tactical role-playing                           Square                              PlayStation  [EA]
# 131  1997                                   Final Fantasy VII              Role-playing                           Square                              PlayStation  [EB]
# 132  1997                                       GoldenEye 007      First-person shooter                         Nintendo                              Nintendo 64  [EC]
# 133  1997                                        Gran Turismo                    Racing      Sony Computer Entertainment                              PlayStation  [ED]
# 134  1997                                    Grand Theft Auto          Action-adventure                  BMG Interactive                                       PC  [EE]
# 135  1997                                            Quake II      First-person shooter                       Activision                                       PC  [EF]
# 136  1997                                         Star Fox 64              Rail shooter                         Nintendo                              Nintendo 64  [EG]
# 137  1997               Star Wars Jedi Knight: Dark Forces II      First-person shooter                        LucasArts                                       PC  [EH]
# 138  1997                                            Tekken 3                  Fighting                            Namco                                   Arcade  [EI]
# 139  1997                                  Total Annihilation        Real-time strategy            Cavedog Entertainment                                  PC, Mac  [EJ]
# 140  1997                                       Ultima Online                    MMORPG                  Electronic Arts                                PC, Linux  [EK]
# 141  1998                                       Baldur's Gate              Role-playing               Black Isle Studios                                       PC  [EL]
# 142  1998                             Crash Bandicoot: Warped                  Platform      Sony Computer Entertainment                              PlayStation  [EM]
# 143  1998                              Dance Dance Revolution                    Rhythm                           Konami                                   Arcade  [EN]
# 144  1998                                           Fallout 2              Role-playing          Interplay Entertainment                                       PC  [EO]
# 145  1998                                       Grim Fandango                 Adventure                        LucasArts                                       PC  [EP]
# 146  1998                                           Half-Life      First-person shooter                   Sierra Studios                                       PC  [EQ]
# 147  1998                The Legend of Zelda: Ocarina of Time          Action-adventure                         Nintendo                              Nintendo 64  [ER]
# 148  1998                                    Metal Gear Solid                   Stealth                           Konami                              PlayStation  [ES]
# 149  1998                                 Panzer Dragoon Saga              Role-playing                             Sega                                   Saturn  [ET]
# 150  1998                                     Resident Evil 2           Survival horror                           Capcom                              PlayStation  [EU]
# 151  1998                                         Soulcalibur                  Fighting                            Namco                                   Arcade  [EV]
# 152  1998                                           StarCraft        Real-time strategy           Blizzard Entertainment                                       PC  [EW]
# 153  1998                                         Suikoden II              Role-playing                           Konami                              PlayStation  [EX]
# 154  1998                             Thief: The Dark Project                   Stealth                Eidos Interactive                                       PC  [EY]
# 155  1999                                   Age of Empires II        Real-time strategy                        Microsoft                                       PC  [EZ]
# 156  1999                                           EverQuest                    MMORPG        Sony Online Entertainment                                       PC  [FA]
# 157  1999                                           Homeworld        Real-time strategy                   Sierra Studios                                       PC  [FB]
# 158  1999                                 Planescape: Torment              Role-playing          Interplay Entertainment                                       PC  [FC]
# 159  1999                            PokÃ©mon Gold and Silver              Role-playing                         Nintendo                           Game Boy Color  [FD]
# 160  1999                                    Quake III: Arena      First-person shooter                       Activision                                       PC  [FE]
# 161  1999                                             Shenmue          Action-adventure                             Sega                                Dreamcast  [FF]
# 162  1999                                         Silent Hill           Survival horror                           Konami                              PlayStation  [FG]
# 163  1999                                      System Shock 2       Action role-playing                  Electronic Arts                                       PC  [FH]
# 164  1999                                   Unreal Tournament      First-person shooter                   GT Interactive                                       PC  [FI]
# 165  2000                    Baldur's Gate II: Shadows of Amn              Role-playing               Black Isle Studios                                       PC  [FJ]
# 166  2000                                      Counter-Strike      First-person shooter                            Valve                                       PC  [FK]
# 167  2000                                             Deus Ex       Action role-playing                Eidos Interactive                                       PC  [FL]
# 168  2000                                           Diablo II       Action role-playing           Blizzard Entertainment                                       PC  [FM]
# 169  2000                                       Jet Set Radio                    Action                             Sega                                Dreamcast  [FN]
# 170  2000                  The Legend of Zelda: Majora's Mask          Action-adventure                         Nintendo                              Nintendo 64  [FO]
# 171  2000                                        Perfect Dark      First-person shooter                             Rare                              Nintendo 64  [FP]
# 172  2000              Marvel vs. Capcom 2: New Age of Heroes                  Fighting                           Capcom                                   Arcade  [FQ]
# 173  2000                                            The Sims           Life simulation                  Electronic Arts                                       PC  [FR]
# 174  2000                             Thief II: The Metal Age                   Stealth                Eidos Interactive                                       PC  [FS]
# 175  2000                            Tony Hawk's Pro Skater 2                    Sports                       Activision                              PlayStation  [FT]
# 176  2000                                       Vagrant Story       Action role-playing                           Square                              PlayStation  [FU]
# 177  2001                                        Advance Wars       Turn-based strategy                         Nintendo                         Game Boy Advance  [FV]
# 178  2001                                     Animal Crossing           Life simulation                         Nintendo                                 GameCube  [FW]
# 179  2001                                       Devil May Cry          Action-adventure                           Capcom                                      PS2  [FX]
# 180  2001                                     Final Fantasy X              Role-playing                           Square                                      PS2  [FY]
# 181  2001                              Gran Turismo 3: A-Spec                    Racing      Sony Computer Entertainment                                      PS2  [FZ]
# 182  2001                                Grand Theft Auto III          Action-adventure                   Rockstar Games                                      PS2  [GA]
# 183  2001                                Halo: Combat Evolved      First-person shooter           Microsoft Game Studios                                     Xbox  [GB]
# 184  2001                                                 Ico          Action-adventure      Sony Computer Entertainment                                      PS2  [GC]
# 185  2001                                             Ikaruga              Shoot 'em up                         Treasure                                   Arcade  [GD]
# 186  2001                                           Max Payne      Third-person shooter          Gathering of Developers                                       PC  [GE]
# 187  2001                 Metal Gear Solid 2: Sons of Liberty                   Stealth                           Konami                                      PS2  [GF]
# 188  2001                        Phoenix Wright: Ace Attorney                 Adventure                           Capcom                         Game Boy Advance  [GG]
# 189  2001                                                 Rez              Rail shooter                             Sega                           Dreamcast, PS2  [GH]
# 190  2001                                       Silent Hill 2           Survival horror                           Konami                                      PS2  [GI]
# 191  2001                             Super Smash Bros. Melee                  Fighting                         Nintendo                                 GameCube  [GJ]
# 192  2001                            Tony Hawk's Pro Skater 3                    Sports                       Activision                         PlayStation, PS2  [GK]
# 193  2002                                    Battlefield 1942      First-person shooter                  Electronic Arts                                       PC  [GL]
# 194  2002                    The Elder Scrolls III: Morrowind       Action role-playing               Bethesda Softworks                                       PC  [GM]
# 195  2002                  Eternal Darkness: Sanity's Requiem           Survival horror                         Nintendo                                 GameCube  [GN]
# 196  2002                         Grand Theft Auto: Vice City          Action-adventure                   Rockstar Games                                      PS2  [GO]
# 197  2002                                      Kingdom Hearts       Action role-playing                           Square                                      PS2  [GP]
# 198  2002                 The Legend of Zelda: The Wind Waker          Action-adventure                         Nintendo                                 GameCube  [GQ]
# 199  2002                                       Metroid Prime          Action-adventure                         Nintendo                                 GameCube  [GR]
# 200  2002                                      Soulcalibur II                  Fighting                            Namco                                   Arcade  [GS]
# 201  2002                          Tom Clancy's Splinter Cell                   Stealth                          Ubisoft                                     Xbox  [GT]
# 202  2002                        Warcraft III: Reign of Chaos        Real-time strategy           Blizzard Entertainment                                  PC, Mac  [GU]
# 203  2003                                  Beyond Good & Evil          Action-adventure                          Ubisoft                                      PS2  [GV]
# 204  2003                                           F-Zero GX                    Racing                         Nintendo                                 GameCube  [GW]
# 205  2003                  Max Payne 2: The Fall of Max Payne      Third-person shooter                   Rockstar Games                                       PC  [GX]
# 206  2003                 Prince of Persia: The Sands of Time          Action-adventure                          Ubisoft                      GameCube, PS2, Xbox  [GY]
# 207  2003              Star Wars: Knights of the Old Republic              Role-playing                        LucasArts                                     Xbox  [GZ]
# 208  2003                   WarioWare, Inc.: Mega Microgames!                    Action                         Nintendo                         Game Boy Advance  [HA]
# 209  2004                                 Burnout 3: Takedown                    Racing                  Electronic Arts                                PS2, Xbox  [HB]
# 210  2004  The Chronicles of Riddick: Escape from Butcher Bay                   Stealth          Vivendi Universal Games                                     Xbox  [HC]
# 211  2004                                   Dragon Quest VIII              Role-playing                      Square Enix                                      PS2  [HD]
# 212  2004                                      Gran Turismo 4                    Racing      Sony Computer Entertainment                                      PS2  [HE]
# 213  2004                       Grand Theft Auto: San Andreas          Action-adventure                   Rockstar Games                                      PS2  [HF]
# 214  2004                                         Half-Life 2      First-person shooter                            Valve                                       PC  [HG]
# 215  2004                                              Halo 2      First-person shooter           Microsoft Game Studios                                     Xbox  [HH]
# 216  2004                                     Katamari Damacy                    Action                            Namco                                      PS2  [HI]
# 217  2004                     Metal Gear Solid 3: Snake Eater                   Stealth                           Konami                                      PS2  [HJ]
# 218  2004                                     Rome: Total War                  Strategy                       Activision                                       PC  [HK]
# 219  2004                                          The Sims 2           Life simulation                  Electronic Arts                                       PC  [HL]
# 220  2004                                   World of Warcraft                    MMORPG           Blizzard Entertainment                                  PC, Mac  [HM]
# 221  2005                                      Call of Duty 2      First-person shooter                       Activision                                       PC  [HN]
# 222  2005                                     Civilization IV       Turn-based strategy                         2K Games                                       PC  [HO]
# 223  2005                  Devil May Cry 3: Dante's Awakening          Action-adventure                           Capcom                                      PS2  [HP]
# 224  2005                                          God of War          Action-adventure      Sony Computer Entertainment                                      PS2  [HQ]
# 225  2005                                         Guitar Hero                    Rhythm                        RedOctane                                      PS2  [HR]
# 226  2005                                         Psychonauts                  Platform                          Majesco                                 PC, Xbox  [HS]
# 227  2005                                     Resident Evil 4           Survival horror                           Capcom                                 GameCube  [HT]
# 228  2005                              Shadow of the Colossus          Action-adventure      Sony Computer Entertainment                                      PS2  [HU]
# 229  2005            Tom Clancy's Splinter Cell: Chaos Theory                   Stealth                          Ubisoft                  GameCube, PC, PS2, Xbox  [HV]
# 230  2006                                   Company of Heroes        Real-time strategy                              THQ                                       PC  [HW]
# 231  2006                      The Elder Scrolls IV: Oblivion       Action role-playing     2K Games, Bethesda Softworks                             PC, Xbox 360  [HX]
# 232  2006                                        Gears of War      Third-person shooter           Microsoft Game Studios                                 Xbox 360  [HY]
# 233  2006                                 Hitman: Blood Money                   Stealth                Eidos Interactive                  PC, PS2, Xbox, Xbox 360  [HZ]
# 234  2006              The Legend of Zelda: Twilight Princess          Action-adventure                         Nintendo                            GameCube, Wii  [IA]
# 235  2006                                              Åkami          Action-adventure                           Capcom                                      PS2  [IB]
# 236  2006                                          Wii Sports                    Sports                         Nintendo                                      Wii  [IC]
# 237  2007                                            BioShock      First-person shooter                         2K Games                             PC, Xbox 360  [ID]
# 238  2007                      Call of Duty 4: Modern Warfare      First-person shooter                       Activision                        PC, PS3, Xbox 360  [IE]
# 239  2007                                       God of War II          Action-adventure      Sony Computer Entertainment                                      PS2  [IF]
# 240  2007                                              Halo 3      First-person shooter           Microsoft Game Studios                                 Xbox 360  [IG]
# 241  2007                                         Mass Effect       Action role-playing           Microsoft Game Studios                                 Xbox 360  [IH]
# 242  2007                                              Peggle                    Puzzle                     PopCap Games                                       PC  [II]
# 243  2007                                              Portal         Puzzle-platformer                            Valve                             PC, Xbox 360  [IJ]
# 244  2007                                           Rock Band                    Rhythm                        MTV Games                            PS3, Xbox 360  [IK]
# 245  2007                                  Super Mario Galaxy                  Platform                         Nintendo                                      Wii  [IL]
# 246  2007                                     Team Fortress 2      First-person shooter                            Valve                             PC, Xbox 360  [IM]
# 247  2007                             The World Ends with You       Action role-playing                      Square Enix                              Nintendo DS  [IN]
# 248  2008                                               Braid         Puzzle-platformer           Microsoft Game Studios                                 Xbox 360  [IO]
# 249  2008                                    Burnout Paradise                    Racing                  Electronic Arts                        PC, PS3, Xbox 360  [IP]
# 250  2008                                          Dead Space           Survival horror                  Electronic Arts                        PC, PS3, Xbox 360  [IQ]
# 251  2008                                            Fable II       Action role-playing           Microsoft Game Studios                                 Xbox 360  [IR]
# 252  2008                                           Fallout 3       Action role-playing               Bethesda Softworks                        PC, PS3, Xbox 360  [IS]
# 253  2008                                      Gears of War 2      Third-person shooter           Microsoft Game Studios                                 Xbox 360  [IT]
# 254  2008                                 Grand Theft Auto IV          Action-adventure                   Rockstar Games                            PS3, Xbox 360  [IU]
# 255  2008                                         Left 4 Dead      First-person shooter                            Valve                             PC, Xbox 360  [IV]
# 256  2008                                     LittleBigPlanet                  Platform      Sony Computer Entertainment                                      PS3  [IW]
# 257  2008                                           Persona 4              Role-playing                            Atlus                                      PS2  [IX]
# 258  2008                                         Rock Band 2                    Rhythm                        MTV Games                                 Xbox 360  [IY]
# 259  2008                                            Spelunky                  Platform                         Derek Yu                                       PC  [IZ]
# 260  2008                                   Street Fighter IV                  Fighting                           Capcom                                   Arcade  [JA]
# 261  2008                             Super Smash Bros. Brawl                  Fighting                         Nintendo                                      Wii  [JB]
# 262  2008                                 Valkyria Chronicles     Tactical role-playing                             Sega                                      PS3  [JC]
# 263  2009                                         Angry Birds                    Puzzle              Rovio Entertainment                               Maemo, iOS  [JD]
# 264  2009                                 Assassin's Creed II          Action-adventure                          Ubisoft                            PS3, Xbox 360  [JE]
# 265  2009                               Batman: Arkham Asylum          Action-adventure  Eidos Interactive, Warner Bros.                            PS3, Xbox 360  [JF]
# 266  2009                                           Bayonetta          Action-adventure                             Sega                            PS3, Xbox 360  [JG]
# 267  2009                                         Borderlands       Action role-playing                         2K Games                        PC, PS3, Xbox 360  [JH]
# 268  2009                                       Demon's Souls       Action role-playing      Sony Computer Entertainment                                      PS3  [JI]
# 269  2009                                 Dragon Age: Origins              Role-playing                  Electronic Arts                        PC, PS3, Xbox 360  [JJ]
# 270  2009                                   League of Legends                      MOBA                       Riot Games                                       PC  [JK]
# 271  2009                                       Left 4 Dead 2      First-person shooter                            Valve                             PC, Xbox 360  [JL]
# 272  2009                                  Plants vs. Zombies             Tower defense                     PopCap Games                                  PC, Mac  [JM]
# 273  2009                          Uncharted 2: Among Thieves          Action-adventure      Sony Computer Entertainment                                      PS3  [JN]
# 274  2010                                      Civilization V       Turn-based strategy                         2K Games                                       PC  [JO]
# 275  2010                                      God of War III          Action-adventure      Sony Computer Entertainment                                      PS3  [JP]
# 276  2010                                          Heavy Rain                 Adventure      Sony Computer Entertainment                                      PS3  [JQ]
# 277  2010                                               Limbo         Puzzle-platformer           Microsoft Game Studios                                 Xbox 360  [JR]
# 278  2010                                       Mass Effect 2       Action role-playing                  Electronic Arts                             PC, Xbox 360  [JS]
# 279  2010                                 Red Dead Redemption          Action-adventure                   Rockstar Games                            PS3, Xbox 360  [JT]
# 280  2010                                         Rock Band 3                    Rhythm                        MTV Games          Nintendo DS, PS3, Xbox 360, Wii  [JU]
# 281  2010                      StarCraft II: Wings of Liberty        Real-time strategy           Blizzard Entertainment                                  PC, Mac  [JV]
# 282  2010                                Super Mario Galaxy 2                  Platform                         Nintendo                                      Wii  [JW]
# 283  2010                                      Super Meat Boy                  Platform                        Team Meat                                 Xbox 360  [JX]
# 284  2010                                Xenoblade Chronicles       Action role-playing                         Nintendo                                      Wii  [JY]
# 285  2011                                 Batman: Arkham City          Action-adventure                     Warner Bros.                            PS3, Xbox 360  [JZ]
# 286  2011                                          Dark Souls       Action role-playing                     Namco Bandai                            PS3, Xbox 360  [KA]
# 287  2011                         The Elder Scrolls V: Skyrim       Action role-playing               Bethesda Softworks                        PC, PS3, Xbox 360  [KB]
# 288  2011                                           Minecraft                   Sandbox                           Mojang                           PC, Mac, Linux  [KC]
# 289  2011                                            Portal 2         Puzzle-platformer                            Valve                        PC, PS3, Xbox 360  [KD]
# 290  2012                                       Borderlands 2       Action role-playing                         2K Games                        PC, PS3, Xbox 360  [KE]
# 291  2012                                          Dishonored                   Stealth               Bethesda Softworks                        PC, PS3, Xbox 360  [KF]
# 292  2012                                           Far Cry 3      First-person shooter                          Ubisoft                        PC, PS3, Xbox 360  [KG]
# 293  2012                               Fire Emblem Awakening     Tactical role-playing                         Nintendo                             Nintendo 3DS  [KH]
# 294  2012                                       Hotline Miami          Top-down shooter                 Devolver Digital                                       PC  [KI]
# 295  2012                                             Journey                 Adventure      Sony Computer Entertainment                                      PS3  [KJ]
# 296  2012                                    The Walking Dead                 Adventure                   Telltale Games                        PC, PS3, Xbox 360  [KK]
# 297  2012                                 XCOM: Enemy Unknown       Turn-based strategy                         2K Games                        PC, PS3, Xbox 360  [KL]
# 298  2013                                   BioShock Infinite      First-person shooter                         2K Games                        PC, PS3, Xbox 360  [KM]
# 299  2013                                              Dota 2                      MOBA                            Valve                                       PC  [KN]
# 300  2013                                  Grand Theft Auto V          Action-adventure                   Rockstar Games                            PS3, Xbox 360  [KO]
# 301  2013                                      The Last of Us          Action-adventure      Sony Computer Entertainment                                      PS3  [KP]
# 302  2013                                      Papers, Please                    Puzzle                         3909 LLC                                  PC, Mac  [KQ]
# 303  2014                                    Alien: Isolation           Survival horror                             Sega         PC, PS3, PS4, Xbox 360, Xbox One  [KR]
# 304  2014                                             Destiny      First-person shooter                       Activision             PS3, PS4, Xbox 360, Xbox One  [KS]
# 305  2014                                         Hearthstone  Digital collectible card           Blizzard Entertainment                                  PC, Mac  [KT]
# 306  2014                                        Mario Kart 8               Kart racing                         Nintendo                                    Wii U  [KU]
# 307  2014                                       Shovel Knight                  Platform                 Yacht Club Games                  Nintendo 3DS, PC, Wii U  [KV]
# 308  2015                                          Bloodborne       Action role-playing      Sony Computer Entertainment                                      PS4  [KW]
# 309  2015                                       Rocket League                    Sports                          Psyonix                                  PC, PS4  [KX]
# 310  2015                                           Undertale              Role-playing                         Toby Fox                                  PC, Mac  [KY]
# 311  2015                            The Witcher 3: Wild Hunt       Action role-playing                       CD Projekt                        PC, PS4, Xbox One  [KZ]
# 312  2016                                        Dishonored 2                   Stealth               Bethesda Softworks                        PC, PS4, Xbox One  [LA]
# 313  2016                                              Inside         Puzzle-platformer                         Playdead                             Xbox One, PC  [LB]
# 314  2016                                           Overwatch      First-person shooter           Blizzard Entertainment                        PC, PS4, Xbox One  [LC]
# 315  2016                                           Persona 5              Role-playing                            Atlus                                 PS3, PS4  [LD]
# 316  2016                                      Stardew Valley      Farm life simulation                      Chucklefish                                       PC  [LE]
# 317  2016                          Uncharted 4: A Thief's End          Action-adventure      Sony Computer Entertainment                                      PS4  [LF]
# 318  2017                                            Fortnite      Third-person shooter                       Epic Games                   PC, Mac, PS4, Xbox One  [LG]
# 319  2017             The Legend of Zelda: Breath of the Wild          Action-adventure                         Nintendo                   Nintendo Switch, Wii U  [LH]
# 320  2017                                 Super Mario Odyssey                  Platform                         Nintendo                          Nintendo Switch  [LI]
# 321  2018                                          God of War          Action-adventure   Sony Interactive Entertainment                                      PS4  [LJ]
# 322  2018                               Red Dead Redemption 2          Action-adventure                   Rockstar Games                            PS4, Xbox One  [LK]
# 323  2018                          Super Smash Bros. Ultimate                  Fighting                         Nintendo                          Nintendo Switch  [LL]
# 324  2019                                       Disco Elysium              Role-playing                            ZA/UM                                       PC  [LM]
# 325  2020                                               Hades       Action role-playing                 Supergiant Games                 PC, Mac, Nintendo Switch  [LN]
# 326  2022                                          Elden Ring       Action role-playing                     Bandai Namco  PC, PS4, PS5, Xbox One, Xbox Series X/S  [LO]

# %%
import pandas as pd
import wikipedia as wp
import sqlite3

# Получаем HTML-страницу из Википедии
html = wp.page("List_of_video_games_considered_the_best").html().encode("UTF-8")

try:
    df = pd.read_html(html)[1]  # Пытаемся получить вторую таблицу
except IndexError:
    df = pd.read_html(html)[0]  # Если второй таблицы нет, берем первую

# Берем первые 300 строк
df = df.iloc[:300, :]

# Создаем таблицы
games_df = df.iloc[:, [0, 2]].rename(columns=lambda x: x.replace(']', '').replace('[', '').strip())  # Название и жанр
games_df.columns = ['name', 'genre']  # Переименовываем столбцы

platforms_df = df.iloc[:, [0, 1, 3]].rename(columns=lambda x: x.replace(']', '').replace('[', '').strip())  # Название, издатель, платформа
platforms_df.columns = ['name', 'publisher', 'platform']  # Переименовываем столбцы

# Создаем соединение с базой данных SQLite
conn = sqlite3.connect("games.db")

# Создаем таблицы
games_df.to_sql("games", conn, if_exists="replace", index=False)
platforms_df.to_sql("platforms", conn, if_exists="replace", index=False)

# Закрываем соединение
conn.close()

print("Таблицы созданы успешно!")


from pypika import Query, Table, Case, functions as fn

# Подключение к базе данных
conn = sqlite3.connect("games.db")
cursor = conn.cursor()

games = Table("games")
platforms = Table("platforms")

# 1. Запрос с JOIN для получения названий игр, жанров и издателей
query = (
    Query.from_(games)
    .join(platforms)
    .on(games.name == platforms.name)
    .select(games.name, games.genre, platforms.publisher)
)
cursor.execute(str(query))
print("Названия игр, жанры и издатели:")
for row in cursor.fetchall():
    print(row)

# 2. Запрос с группировкой и подсчетом количества игр для каждого жанра
query = (
    Query.from_(games)
    .select(games.genre, fn.Count(games.name).as_("game_count"))
    .groupby(games.genre)
)
cursor.execute(str(query))
print("\nКоличество игр по жанрам:")
for row in cursor.fetchall():
    print(row)

# Закрытие соединения с базой данных
conn.close()
# Out:
# Таблицы созданы успешно!
# Названия игр, жанры и издатели:
# (1971, 'Strategy', 'The Oregon Trail')
# (1972, 'Sports', 'Pong')
# (1977, 'Top-down shooter', 'Combat')
# (1977, 'Top-down shooter', 'Zork')
# (1977, 'Adventure', 'Combat')
# (1977, 'Adventure', 'Zork')
# (1978, "Shoot 'em up", 'Space Invaders')
# (1979, "Shoot 'em up", 'Asteroids')
# (1980, 'Action-adventure', 'Adventure')
# (1980, 'Action-adventure', 'Battlezone')
# (1980, 'Action-adventure', 'Missile Command')
# (1980, 'Action-adventure', 'Pac-Man')
# (1980, 'Vehicle simulation', 'Adventure')
# (1980, 'Vehicle simulation', 'Battlezone')
# (1980, 'Vehicle simulation', 'Missile Command')
# (1980, 'Vehicle simulation', 'Pac-Man')
# (1980, "Shoot 'em up", 'Adventure')
# (1980, "Shoot 'em up", 'Battlezone')
# (1980, "Shoot 'em up", 'Missile Command')
# (1980, "Shoot 'em up", 'Pac-Man')
# (1980, 'Maze', 'Adventure')
# (1980, 'Maze', 'Battlezone')
# (1980, 'Maze', 'Missile Command')
# (1980, 'Maze', 'Pac-Man')
# (1981, "Shoot 'em up", 'Centipede')
# (1981, "Shoot 'em up", 'Defender')
# (1981, "Shoot 'em up", 'Donkey Kong')
# (1981, "Shoot 'em up", 'Frogger')
# (1981, "Shoot 'em up", 'Galaga')
# (1981, "Shoot 'em up", 'Tempest')
# (1981, "Shoot 'em up", 'Wizardry: Proving Grounds of the Mad Overlord')
# (1981, "Shoot 'em up", 'Centipede')
# (1981, "Shoot 'em up", 'Defender')
# (1981, "Shoot 'em up", 'Donkey Kong')
# (1981, "Shoot 'em up", 'Frogger')
# (1981, "Shoot 'em up", 'Galaga')
# (1981, "Shoot 'em up", 'Tempest')
# (1981, "Shoot 'em up", 'Wizardry: Proving Grounds of the Mad Overlord')
# (1981, 'Platform', 'Centipede')
# (1981, 'Platform', 'Defender')
# (1981, 'Platform', 'Donkey Kong')
# (1981, 'Platform', 'Frogger')
# (1981, 'Platform', 'Galaga')
# (1981, 'Platform', 'Tempest')
# (1981, 'Platform', 'Wizardry: Proving Grounds of the Mad Overlord')
# (1981, 'Action', 'Centipede')
# (1981, 'Action', 'Defender')
# (1981, 'Action', 'Donkey Kong')
# (1981, 'Action', 'Frogger')
# (1981, 'Action', 'Galaga')
# (1981, 'Action', 'Tempest')
# (1981, 'Action', 'Wizardry: Proving Grounds of the Mad Overlord')
# (1981, "Shoot 'em up", 'Centipede')
# (1981, "Shoot 'em up", 'Defender')
# (1981, "Shoot 'em up", 'Donkey Kong')
# (1981, "Shoot 'em up", 'Frogger')
# (1981, "Shoot 'em up", 'Galaga')
# (1981, "Shoot 'em up", 'Tempest')
# (1981, "Shoot 'em up", 'Wizardry: Proving Grounds of the Mad Overlord')
# (1981, "Shoot 'em up", 'Centipede')
# (1981, "Shoot 'em up", 'Defender')
# (1981, "Shoot 'em up", 'Donkey Kong')
# (1981, "Shoot 'em up", 'Frogger')
# (1981, "Shoot 'em up", 'Galaga')
# (1981, "Shoot 'em up", 'Tempest')
# (1981, "Shoot 'em up", 'Wizardry: Proving Grounds of the Mad Overlord')
# (1981, 'Role-playing', 'Centipede')
# (1981, 'Role-playing', 'Defender')
# (1981, 'Role-playing', 'Donkey Kong')
# (1981, 'Role-playing', 'Frogger')
# (1981, 'Role-playing', 'Galaga')
# (1981, 'Role-playing', 'Tempest')
# (1981, 'Role-playing', 'Wizardry: Proving Grounds of the Mad Overlord')
# (1982, 'Action', 'Joust')
# (1982, 'Action', 'Ms. Pac-Man')
# (1982, 'Action', 'Pitfall!')
# (1982, 'Action', 'Robotron: 2084')
# (1982, 'Maze', 'Joust')
# (1982, 'Maze', 'Ms. Pac-Man')
# (1982, 'Maze', 'Pitfall!')
# (1982, 'Maze', 'Robotron: 2084')
# (1982, 'Platform', 'Joust')
# (1982, 'Platform', 'Ms. Pac-Man')
# (1982, 'Platform', 'Pitfall!')
# (1982, 'Platform', 'Robotron: 2084')
# (1982, 'Top-down shooter', 'Joust')
# (1982, 'Top-down shooter', 'Ms. Pac-Man')
# (1982, 'Top-down shooter', 'Pitfall!')
# (1982, 'Top-down shooter', 'Robotron: 2084')
# (1983, 'Strategy', 'Archon: The Light and the Dark')
# (1983, 'Strategy', 'Lode Runner')
# (1983, 'Strategy', 'M.U.L.E.')
# (1983, 'Strategy', 'Star Wars')
# (1983, 'Platform', 'Archon: The Light and the Dark')
# (1983, 'Platform', 'Lode Runner')
# (1983, 'Platform', 'M.U.L.E.')
# (1983, 'Platform', 'Star Wars')
# (1983, 'Business simulation', 'Archon: The Light and the Dark')
# (1983, 'Business simulation', 'Lode Runner')
# (1983, 'Business simulation', 'M.U.L.E.')
# (1983, 'Business simulation', 'Star Wars')
# (1983, 'Rail shooter', 'Archon: The Light and the Dark')
# (1983, 'Rail shooter', 'Lode Runner')
# (1983, 'Rail shooter', 'M.U.L.E.')
# (1983, 'Rail shooter', 'Star Wars')
# (1984, 'Space flight simulator', 'Elite')
# (1984, 'Space flight simulator', 'Marble Madness')
# (1984, 'Action', 'Elite')
# (1984, 'Action', 'Marble Madness')
# (1985, 'Hack and slash', 'Gauntlet')
# (1985, 'Hack and slash', "Ghosts 'n Goblins")
# (1985, 'Hack and slash', 'Super Mario Bros.')
# (1985, 'Hack and slash', 'Tetris')
# (1985, 'Hack and slash', 'Ultima IV: Quest of the Avatar')
# (1985, 'Platform', 'Gauntlet')
# (1985, 'Platform', "Ghosts 'n Goblins")
# (1985, 'Platform', 'Super Mario Bros.')
# (1985, 'Platform', 'Tetris')
# (1985, 'Platform', 'Ultima IV: Quest of the Avatar')
# (1985, 'Platform', 'Gauntlet')
# (1985, 'Platform', "Ghosts 'n Goblins")
# (1985, 'Platform', 'Super Mario Bros.')
# (1985, 'Platform', 'Tetris')
# (1985, 'Platform', 'Ultima IV: Quest of the Avatar')
# (1985, 'Puzzle', 'Gauntlet')
# (1985, 'Puzzle', "Ghosts 'n Goblins")
# (1985, 'Puzzle', 'Super Mario Bros.')
# (1985, 'Puzzle', 'Tetris')
# (1985, 'Puzzle', 'Ultima IV: Quest of the Avatar')
# (1985, 'Role-playing', 'Gauntlet')
# (1985, 'Role-playing', "Ghosts 'n Goblins")
# (1985, 'Role-playing', 'Super Mario Bros.')
# (1985, 'Role-playing', 'Tetris')
# (1985, 'Role-playing', 'Ultima IV: Quest of the Avatar')
# (1986, 'Block breaker', 'Arkanoid')
# (1986, 'Block breaker', 'Bubble Bobble')
# (1986, 'Block breaker', 'Out Run')
# (1986, 'Block breaker', 'The Legend of Zelda')
# (1986, 'Platform', 'Arkanoid')
# (1986, 'Platform', 'Bubble Bobble')
# (1986, 'Platform', 'Out Run')
# (1986, 'Platform', 'The Legend of Zelda')
# (1986, 'Action-adventure', 'Arkanoid')
# (1986, 'Action-adventure', 'Bubble Bobble')
# (1986, 'Action-adventure', 'Out Run')
# (1986, 'Action-adventure', 'The Legend of Zelda')
# (1986, 'Racing', 'Arkanoid')
# (1986, 'Racing', 'Bubble Bobble')
# (1986, 'Racing', 'Out Run')
# (1986, 'Racing', 'The Legend of Zelda')
# (1987, 'Run and gun', 'Contra')
# (1987, 'Run and gun', 'Double Dragon')
# (1987, 'Run and gun', 'Dungeon Master')
# (1987, 'Run and gun', "Mike Tyson's Punch-Out!!")
# (1987, 'Run and gun', 'R-Type')
# (1987, 'Run and gun', "Sid Meier's Pirates!")
# (1987, "Beat 'em up", 'Contra')
# (1987, "Beat 'em up", 'Double Dragon')
# (1987, "Beat 'em up", 'Dungeon Master')
# (1987, "Beat 'em up", "Mike Tyson's Punch-Out!!")
# (1987, "Beat 'em up", 'R-Type')
# (1987, "Beat 'em up", "Sid Meier's Pirates!")
# (1987, 'Role-playing', 'Contra')
# (1987, 'Role-playing', 'Double Dragon')
# (1987, 'Role-playing', 'Dungeon Master')
# (1987, 'Role-playing', "Mike Tyson's Punch-Out!!")
# (1987, 'Role-playing', 'R-Type')
# (1987, 'Role-playing', "Sid Meier's Pirates!")
# (1987, 'Sports', 'Contra')
# (1987, 'Sports', 'Double Dragon')
# (1987, 'Sports', 'Dungeon Master')
# (1987, 'Sports', "Mike Tyson's Punch-Out!!")
# (1987, 'Sports', 'R-Type')
# (1987, 'Sports', "Sid Meier's Pirates!")
# (1987, "Shoot 'em up", 'Contra')
# (1987, "Shoot 'em up", 'Double Dragon')
# (1987, "Shoot 'em up", 'Dungeon Master')
# (1987, "Shoot 'em up", "Mike Tyson's Punch-Out!!")
# (1987, "Shoot 'em up", 'R-Type')
# (1987, "Shoot 'em up", "Sid Meier's Pirates!")
# (1987, 'Action-adventure', 'Contra')
# (1987, 'Action-adventure', 'Double Dragon')
# (1987, 'Action-adventure', 'Dungeon Master')
# (1987, 'Action-adventure', "Mike Tyson's Punch-Out!!")
# (1987, 'Action-adventure', 'R-Type')
# (1987, 'Action-adventure', "Sid Meier's Pirates!")
# (1988, 'Platform', 'Mega Man 2')
# (1988, 'Platform', 'Ninja Gaiden')
# (1988, 'Platform', 'Super Mario Bros. 3')
# (1988, 'Platform', 'Mega Man 2')
# (1988, 'Platform', 'Ninja Gaiden')
# (1988, 'Platform', 'Super Mario Bros. 3')
# (1988, 'Platform', 'Mega Man 2')
# (1988, 'Platform', 'Ninja Gaiden')
# (1988, 'Platform', 'Super Mario Bros. 3')
# (1989, "Beat 'em up", 'Final Fight')
# (1989, "Beat 'em up", 'Populous')
# (1989, "Beat 'em up", 'Prince of Persia')
# (1989, "Beat 'em up", 'SimCity')
# (1989, 'God game', 'Final Fight')
# (1989, 'God game', 'Populous')
# (1989, 'God game', 'Prince of Persia')
# (1989, 'God game', 'SimCity')
# (1989, 'Platform', 'Final Fight')
# (1989, 'Platform', 'Populous')
# (1989, 'Platform', 'Prince of Persia')
# (1989, 'Platform', 'SimCity')
# (1989, 'City-building', 'Final Fight')
# (1989, 'City-building', 'Populous')
# (1989, 'City-building', 'Prince of Persia')
# (1989, 'City-building', 'SimCity')
# (1990, 'Adventure', 'Speedball 2: Brutal Deluxe')
# (1990, 'Adventure', 'Super Mario World')
# (1990, 'Adventure', 'The Secret of Monkey Island')
# (1990, 'Adventure', 'Wing Commander')
# (1990, 'Sports', 'Speedball 2: Brutal Deluxe')
# (1990, 'Sports', 'Super Mario World')
# (1990, 'Sports', 'The Secret of Monkey Island')
# (1990, 'Sports', 'Wing Commander')
# (1990, 'Platform', 'Speedball 2: Brutal Deluxe')
# (1990, 'Platform', 'Super Mario World')
# (1990, 'Platform', 'The Secret of Monkey Island')
# (1990, 'Platform', 'Wing Commander')
# (1990, 'Space flight simulator', 'Speedball 2: Brutal Deluxe')
# (1990, 'Space flight simulator', 'Super Mario World')
# (1990, 'Space flight simulator', 'The Secret of Monkey Island')
# (1990, 'Space flight simulator', 'Wing Commander')
# (1991, 'Platform', 'Another World')
# (1991, 'Platform', 'Civilization')
# (1991, 'Platform', 'Final Fantasy IV')
# (1991, 'Platform', 'Lemmings')
# (1991, 'Platform', 'Micro Machines')
# (1991, 'Platform', "Monkey Island 2: LeChuck's Revenge")
# (1991, 'Platform', 'Sonic the Hedgehog')
# (1991, 'Platform', 'Street Fighter II')
# (1991, 'Platform', 'Super Castlevania IV')
# (1991, 'Platform', 'The Legend of Zelda: A Link to the Past')
# (1991, 'Turn-based strategy', 'Another World')
# (1991, 'Turn-based strategy', 'Civilization')
# (1991, 'Turn-based strategy', 'Final Fantasy IV')
# (1991, 'Turn-based strategy', 'Lemmings')
# (1991, 'Turn-based strategy', 'Micro Machines')
# (1991, 'Turn-based strategy', "Monkey Island 2: LeChuck's Revenge")
# (1991, 'Turn-based strategy', 'Sonic the Hedgehog')
# (1991, 'Turn-based strategy', 'Street Fighter II')
# (1991, 'Turn-based strategy', 'Super Castlevania IV')
# (1991, 'Turn-based strategy', 'The Legend of Zelda: A Link to the Past')
# (1991, 'Role-playing', 'Another World')
# (1991, 'Role-playing', 'Civilization')
# (1991, 'Role-playing', 'Final Fantasy IV')
# (1991, 'Role-playing', 'Lemmings')
# (1991, 'Role-playing', 'Micro Machines')
# (1991, 'Role-playing', "Monkey Island 2: LeChuck's Revenge")
# (1991, 'Role-playing', 'Sonic the Hedgehog')
# (1991, 'Role-playing', 'Street Fighter II')
# (1991, 'Role-playing', 'Super Castlevania IV')
# (1991, 'Role-playing', 'The Legend of Zelda: A Link to the Past')
# (1991, 'Action-adventure', 'Another World')
# (1991, 'Action-adventure', 'Civilization')
# (1991, 'Action-adventure', 'Final Fantasy IV')
# (1991, 'Action-adventure', 'Lemmings')
# (1991, 'Action-adventure', 'Micro Machines')
# (1991, 'Action-adventure', "Monkey Island 2: LeChuck's Revenge")
# (1991, 'Action-adventure', 'Sonic the Hedgehog')
# (1991, 'Action-adventure', 'Street Fighter II')
# (1991, 'Action-adventure', 'Super Castlevania IV')
# (1991, 'Action-adventure', 'The Legend of Zelda: A Link to the Past')
# (1991, 'Puzzle', 'Another World')
# (1991, 'Puzzle', 'Civilization')
# (1991, 'Puzzle', 'Final Fantasy IV')
# (1991, 'Puzzle', 'Lemmings')
# (1991, 'Puzzle', 'Micro Machines')
# (1991, 'Puzzle', "Monkey Island 2: LeChuck's Revenge")
# (1991, 'Puzzle', 'Sonic the Hedgehog')
# (1991, 'Puzzle', 'Street Fighter II')
# (1991, 'Puzzle', 'Super Castlevania IV')
# (1991, 'Puzzle', 'The Legend of Zelda: A Link to the Past')
# (1991, 'Racing', 'Another World')
# (1991, 'Racing', 'Civilization')
# (1991, 'Racing', 'Final Fantasy IV')
# (1991, 'Racing', 'Lemmings')
# (1991, 'Racing', 'Micro Machines')
# (1991, 'Racing', "Monkey Island 2: LeChuck's Revenge")
# (1991, 'Racing', 'Sonic the Hedgehog')
# (1991, 'Racing', 'Street Fighter II')
# (1991, 'Racing', 'Super Castlevania IV')
# (1991, 'Racing', 'The Legend of Zelda: A Link to the Past')
# (1991, 'Adventure', 'Another World')
# (1991, 'Adventure', 'Civilization')
# (1991, 'Adventure', 'Final Fantasy IV')
# (1991, 'Adventure', 'Lemmings')
# (1991, 'Adventure', 'Micro Machines')
# (1991, 'Adventure', "Monkey Island 2: LeChuck's Revenge")
# (1991, 'Adventure', 'Sonic the Hedgehog')
# (1991, 'Adventure', 'Street Fighter II')
# (1991, 'Adventure', 'Super Castlevania IV')
# (1991, 'Adventure', 'The Legend of Zelda: A Link to the Past')
# (1991, 'Platform', 'Another World')
# (1991, 'Platform', 'Civilization')
# (1991, 'Platform', 'Final Fantasy IV')
# (1991, 'Platform', 'Lemmings')
# (1991, 'Platform', 'Micro Machines')
# (1991, 'Platform', "Monkey Island 2: LeChuck's Revenge")
# (1991, 'Platform', 'Sonic the Hedgehog')
# (1991, 'Platform', 'Street Fighter II')
# (1991, 'Platform', 'Super Castlevania IV')
# (1991, 'Platform', 'The Legend of Zelda: A Link to the Past')
# (1991, 'Fighting', 'Another World')
# (1991, 'Fighting', 'Civilization')
# (1991, 'Fighting', 'Final Fantasy IV')
# (1991, 'Fighting', 'Lemmings')
# (1991, 'Fighting', 'Micro Machines')
# (1991, 'Fighting', "Monkey Island 2: LeChuck's Revenge")
# (1991, 'Fighting', 'Sonic the Hedgehog')
# (1991, 'Fighting', 'Street Fighter II')
# (1991, 'Fighting', 'Super Castlevania IV')
# (1991, 'Fighting', 'The Legend of Zelda: A Link to the Past')
# (1991, 'Platform', 'Another World')
# (1991, 'Platform', 'Civilization')
# (1991, 'Platform', 'Final Fantasy IV')
# (1991, 'Platform', 'Lemmings')
# (1991, 'Platform', 'Micro Machines')
# (1991, 'Platform', "Monkey Island 2: LeChuck's Revenge")
# (1991, 'Platform', 'Sonic the Hedgehog')
# (1991, 'Platform', 'Street Fighter II')
# (1991, 'Platform', 'Super Castlevania IV')
# (1991, 'Platform', 'The Legend of Zelda: A Link to the Past')
# (1992, 'Survival horror', 'Alone in the Dark')
# (1992, 'Survival horror', 'Contra III: The Alien Wars')
# (1992, 'Survival horror', 'Dune II')
# (1992, 'Survival horror', 'Flashback')
# (1992, 'Survival horror', 'Indiana Jones and the Fate of Atlantis')
# (1992, 'Survival horror', 'Mortal Kombat')
# (1992, 'Survival horror', 'Sensible Soccer')
# (1992, 'Survival horror', 'Sonic the Hedgehog 2')
# (1992, 'Survival horror', 'Star Control II')
# (1992, 'Survival horror', 'Streets of Rage 2')
# (1992, 'Survival horror', 'Super Mario Kart')
# (1992, 'Survival horror', 'Ultima VII: The Black Gate')
# (1992, 'Survival horror', 'Virtua Racing')
# (1992, 'Survival horror', 'Wolfenstein 3D')
# (1992, 'Run and gun', 'Alone in the Dark')
# (1992, 'Run and gun', 'Contra III: The Alien Wars')
# (1992, 'Run and gun', 'Dune II')
# (1992, 'Run and gun', 'Flashback')
# (1992, 'Run and gun', 'Indiana Jones and the Fate of Atlantis')
# (1992, 'Run and gun', 'Mortal Kombat')
# (1992, 'Run and gun', 'Sensible Soccer')
# (1992, 'Run and gun', 'Sonic the Hedgehog 2')
# (1992, 'Run and gun', 'Star Control II')
# (1992, 'Run and gun', 'Streets of Rage 2')
# (1992, 'Run and gun', 'Super Mario Kart')
# (1992, 'Run and gun', 'Ultima VII: The Black Gate')
# (1992, 'Run and gun', 'Virtua Racing')
# (1992, 'Run and gun', 'Wolfenstein 3D')
# (1992, 'Real-time strategy', 'Alone in the Dark')
# (1992, 'Real-time strategy', 'Contra III: The Alien Wars')
# (1992, 'Real-time strategy', 'Dune II')
# (1992, 'Real-time strategy', 'Flashback')
# (1992, 'Real-time strategy', 'Indiana Jones and the Fate of Atlantis')
# (1992, 'Real-time strategy', 'Mortal Kombat')
# (1992, 'Real-time strategy', 'Sensible Soccer')
# (1992, 'Real-time strategy', 'Sonic the Hedgehog 2')
# (1992, 'Real-time strategy', 'Star Control II')
# (1992, 'Real-time strategy', 'Streets of Rage 2')
# (1992, 'Real-time strategy', 'Super Mario Kart')
# (1992, 'Real-time strategy', 'Ultima VII: The Black Gate')
# (1992, 'Real-time strategy', 'Virtua Racing')
# (1992, 'Real-time strategy', 'Wolfenstein 3D')
# (1992, 'Platform', 'Alone in the Dark')
# (1992, 'Platform', 'Contra III: The Alien Wars')
# (1992, 'Platform', 'Dune II')
# (1992, 'Platform', 'Flashback')
# (1992, 'Platform', 'Indiana Jones and the Fate of Atlantis')
# (1992, 'Platform', 'Mortal Kombat')
# (1992, 'Platform', 'Sensible Soccer')
# (1992, 'Platform', 'Sonic the Hedgehog 2')
# (1992, 'Platform', 'Star Control II')
# (1992, 'Platform', 'Streets of Rage 2')
# (1992, 'Platform', 'Super Mario Kart')
# (1992, 'Platform', 'Ultima VII: The Black Gate')
# (1992, 'Platform', 'Virtua Racing')
# (1992, 'Platform', 'Wolfenstein 3D')
# (1992, 'Adventure', 'Alone in the Dark')
# (1992, 'Adventure', 'Contra III: The Alien Wars')
# (1992, 'Adventure', 'Dune II')
# (1992, 'Adventure', 'Flashback')
# (1992, 'Adventure', 'Indiana Jones and the Fate of Atlantis')
# (1992, 'Adventure', 'Mortal Kombat')
# (1992, 'Adventure', 'Sensible Soccer')
# (1992, 'Adventure', 'Sonic the Hedgehog 2')
# (1992, 'Adventure', 'Star Control II')
# (1992, 'Adventure', 'Streets of Rage 2')
# (1992, 'Adventure', 'Super Mario Kart')
# (1992, 'Adventure', 'Ultima VII: The Black Gate')
# (1992, 'Adventure', 'Virtua Racing')
# (1992, 'Adventure', 'Wolfenstein 3D')
# (1992, 'Fighting', 'Alone in the Dark')
# (1992, 'Fighting', 'Contra III: The Alien Wars')
# (1992, 'Fighting', 'Dune II')
# (1992, 'Fighting', 'Flashback')
# (1992, 'Fighting', 'Indiana Jones and the Fate of Atlantis')
# (1992, 'Fighting', 'Mortal Kombat')
# (1992, 'Fighting', 'Sensible Soccer')
# (1992, 'Fighting', 'Sonic the Hedgehog 2')
# (1992, 'Fighting', 'Star Control II')
# (1992, 'Fighting', 'Streets of Rage 2')
# (1992, 'Fighting', 'Super Mario Kart')
# (1992, 'Fighting', 'Ultima VII: The Black Gate')
# (1992, 'Fighting', 'Virtua Racing')
# (1992, 'Fighting', 'Wolfenstein 3D')
# (1992, 'Sports', 'Alone in the Dark')
# (1992, 'Sports', 'Contra III: The Alien Wars')
# (1992, 'Sports', 'Dune II')
# (1992, 'Sports', 'Flashback')
# (1992, 'Sports', 'Indiana Jones and the Fate of Atlantis')
# (1992, 'Sports', 'Mortal Kombat')
# (1992, 'Sports', 'Sensible Soccer')
# (1992, 'Sports', 'Sonic the Hedgehog 2')
# (1992, 'Sports', 'Star Control II')
# (1992, 'Sports', 'Streets of Rage 2')
# (1992, 'Sports', 'Super Mario Kart')
# (1992, 'Sports', 'Ultima VII: The Black Gate')
# (1992, 'Sports', 'Virtua Racing')
# (1992, 'Sports', 'Wolfenstein 3D')
# (1992, 'Platform', 'Alone in the Dark')
# (1992, 'Platform', 'Contra III: The Alien Wars')
# (1992, 'Platform', 'Dune II')
# (1992, 'Platform', 'Flashback')
# (1992, 'Platform', 'Indiana Jones and the Fate of Atlantis')
# (1992, 'Platform', 'Mortal Kombat')
# (1992, 'Platform', 'Sensible Soccer')
# (1992, 'Platform', 'Sonic the Hedgehog 2')
# (1992, 'Platform', 'Star Control II')
# (1992, 'Platform', 'Streets of Rage 2')
# (1992, 'Platform', 'Super Mario Kart')
# (1992, 'Platform', 'Ultima VII: The Black Gate')
# (1992, 'Platform', 'Virtua Racing')
# (1992, 'Platform', 'Wolfenstein 3D')
# (1992, 'Action-adventure', 'Alone in the Dark')
# (1992, 'Action-adventure', 'Contra III: The Alien Wars')
# (1992, 'Action-adventure', 'Dune II')
# (1992, 'Action-adventure', 'Flashback')
# (1992, 'Action-adventure', 'Indiana Jones and the Fate of Atlantis')
# (1992, 'Action-adventure', 'Mortal Kombat')
# (1992, 'Action-adventure', 'Sensible Soccer')
# (1992, 'Action-adventure', 'Sonic the Hedgehog 2')
# (1992, 'Action-adventure', 'Star Control II')
# (1992, 'Action-adventure', 'Streets of Rage 2')
# (1992, 'Action-adventure', 'Super Mario Kart')
# (1992, 'Action-adventure', 'Ultima VII: The Black Gate')
# (1992, 'Action-adventure', 'Virtua Racing')
# (1992, 'Action-adventure', 'Wolfenstein 3D')
# (1992, "Beat 'em up", 'Alone in the Dark')
# (1992, "Beat 'em up", 'Contra III: The Alien Wars')
# (1992, "Beat 'em up", 'Dune II')
# (1992, "Beat 'em up", 'Flashback')
# (1992, "Beat 'em up", 'Indiana Jones and the Fate of Atlantis')
# (1992, "Beat 'em up", 'Mortal Kombat')
# (1992, "Beat 'em up", 'Sensible Soccer')
# (1992, "Beat 'em up", 'Sonic the Hedgehog 2')
# (1992, "Beat 'em up", 'Star Control II')
# (1992, "Beat 'em up", 'Streets of Rage 2')
# (1992, "Beat 'em up", 'Super Mario Kart')
# (1992, "Beat 'em up", 'Ultima VII: The Black Gate')
# (1992, "Beat 'em up", 'Virtua Racing')
# (1992, "Beat 'em up", 'Wolfenstein 3D')
# (1992, 'Kart racing', 'Alone in the Dark')
# (1992, 'Kart racing', 'Contra III: The Alien Wars')
# (1992, 'Kart racing', 'Dune II')
# (1992, 'Kart racing', 'Flashback')
# (1992, 'Kart racing', 'Indiana Jones and the Fate of Atlantis')
# (1992, 'Kart racing', 'Mortal Kombat')
# (1992, 'Kart racing', 'Sensible Soccer')
# (1992, 'Kart racing', 'Sonic the Hedgehog 2')
# (1992, 'Kart racing', 'Star Control II')
# (1992, 'Kart racing', 'Streets of Rage 2')
# (1992, 'Kart racing', 'Super Mario Kart')
# (1992, 'Kart racing', 'Ultima VII: The Black Gate')
# (1992, 'Kart racing', 'Virtua Racing')
# (1992, 'Kart racing', 'Wolfenstein 3D')
# (1992, 'Role-playing', 'Alone in the Dark')
# (1992, 'Role-playing', 'Contra III: The Alien Wars')
# (1992, 'Role-playing', 'Dune II')
# (1992, 'Role-playing', 'Flashback')
# (1992, 'Role-playing', 'Indiana Jones and the Fate of Atlantis')
# (1992, 'Role-playing', 'Mortal Kombat')
# (1992, 'Role-playing', 'Sensible Soccer')
# (1992, 'Role-playing', 'Sonic the Hedgehog 2')
# (1992, 'Role-playing', 'Star Control II')
# (1992, 'Role-playing', 'Streets of Rage 2')
# (1992, 'Role-playing', 'Super Mario Kart')
# (1992, 'Role-playing', 'Ultima VII: The Black Gate')
# (1992, 'Role-playing', 'Virtua Racing')
# (1992, 'Role-playing', 'Wolfenstein 3D')
# (1992, 'Racing', 'Alone in the Dark')
# (1992, 'Racing', 'Contra III: The Alien Wars')
# (1992, 'Racing', 'Dune II')
# (1992, 'Racing', 'Flashback')
# (1992, 'Racing', 'Indiana Jones and the Fate of Atlantis')
# (1992, 'Racing', 'Mortal Kombat')
# (1992, 'Racing', 'Sensible Soccer')
# (1992, 'Racing', 'Sonic the Hedgehog 2')
# (1992, 'Racing', 'Star Control II')
# (1992, 'Racing', 'Streets of Rage 2')
# (1992, 'Racing', 'Super Mario Kart')
# (1992, 'Racing', 'Ultima VII: The Black Gate')
# (1992, 'Racing', 'Virtua Racing')
# (1992, 'Racing', 'Wolfenstein 3D')
# (1992, 'First-person shooter', 'Alone in the Dark')
# (1992, 'First-person shooter', 'Contra III: The Alien Wars')
# (1992, 'First-person shooter', 'Dune II')
# (1992, 'First-person shooter', 'Flashback')
# (1992, 'First-person shooter', 'Indiana Jones and the Fate of Atlantis')
# (1992, 'First-person shooter', 'Mortal Kombat')
# (1992, 'First-person shooter', 'Sensible Soccer')
# (1992, 'First-person shooter', 'Sonic the Hedgehog 2')
# (1992, 'First-person shooter', 'Star Control II')
# (1992, 'First-person shooter', 'Streets of Rage 2')
# (1992, 'First-person shooter', 'Super Mario Kart')
# (1992, 'First-person shooter', 'Ultima VII: The Black Gate')
# (1992, 'First-person shooter', 'Virtua Racing')
# (1992, 'First-person shooter', 'Wolfenstein 3D')
# (1993, 'Adventure', 'Day of the Tentacle')
# (1993, 'Adventure', 'Doom')
# (1993, 'Adventure', 'Gunstar Heroes')
# (1993, 'Adventure', 'Mega Man X')
# (1993, 'Adventure', 'Mortal Kombat II')
# (1993, 'Adventure', 'Myst')
# (1993, 'Adventure', 'NBA Jam')
# (1993, 'Adventure', 'Phantasy Star IV')
# (1993, 'Adventure', 'Ridge Racer')
# (1993, 'Adventure', 'Sam & Max Hit the Road')
# (1993, 'Adventure', 'Samurai Shodown')
# (1993, 'Adventure', 'Secret of Mana')
# (1993, 'Adventure', 'SimCity 2000')
# (1993, 'Adventure', 'Star Fox')
# (1993, 'Adventure', 'Syndicate')
# (1993, 'Adventure', "The Legend of Zelda: Link's Awakening")
# (1993, 'First-person shooter', 'Day of the Tentacle')
# (1993, 'First-person shooter', 'Doom')
# (1993, 'First-person shooter', 'Gunstar Heroes')
# (1993, 'First-person shooter', 'Mega Man X')
# (1993, 'First-person shooter', 'Mortal Kombat II')
# (1993, 'First-person shooter', 'Myst')
# (1993, 'First-person shooter', 'NBA Jam')
# (1993, 'First-person shooter', 'Phantasy Star IV')
# (1993, 'First-person shooter', 'Ridge Racer')
# (1993, 'First-person shooter', 'Sam & Max Hit the Road')
# (1993, 'First-person shooter', 'Samurai Shodown')
# (1993, 'First-person shooter', 'Secret of Mana')
# (1993, 'First-person shooter', 'SimCity 2000')
# (1993, 'First-person shooter', 'Star Fox')
# (1993, 'First-person shooter', 'Syndicate')
# (1993, 'First-person shooter', "The Legend of Zelda: Link's Awakening")
# (1993, 'Run and gun', 'Day of the Tentacle')
# (1993, 'Run and gun', 'Doom')
# (1993, 'Run and gun', 'Gunstar Heroes')
# (1993, 'Run and gun', 'Mega Man X')
# (1993, 'Run and gun', 'Mortal Kombat II')
# (1993, 'Run and gun', 'Myst')
# (1993, 'Run and gun', 'NBA Jam')
# (1993, 'Run and gun', 'Phantasy Star IV')
# (1993, 'Run and gun', 'Ridge Racer')
# (1993, 'Run and gun', 'Sam & Max Hit the Road')
# (1993, 'Run and gun', 'Samurai Shodown')
# (1993, 'Run and gun', 'Secret of Mana')
# (1993, 'Run and gun', 'SimCity 2000')
# (1993, 'Run and gun', 'Star Fox')
# (1993, 'Run and gun', 'Syndicate')
# (1993, 'Run and gun', "The Legend of Zelda: Link's Awakening")
# (1993, 'Action-adventure', 'Day of the Tentacle')
# (1993, 'Action-adventure', 'Doom')
# (1993, 'Action-adventure', 'Gunstar Heroes')
# (1993, 'Action-adventure', 'Mega Man X')
# (1993, 'Action-adventure', 'Mortal Kombat II')
# (1993, 'Action-adventure', 'Myst')
# (1993, 'Action-adventure', 'NBA Jam')
# (1993, 'Action-adventure', 'Phantasy Star IV')
# (1993, 'Action-adventure', 'Ridge Racer')
# (1993, 'Action-adventure', 'Sam & Max Hit the Road')
# (1993, 'Action-adventure', 'Samurai Shodown')
# (1993, 'Action-adventure', 'Secret of Mana')
# (1993, 'Action-adventure', 'SimCity 2000')
# (1993, 'Action-adventure', 'Star Fox')
# (1993, 'Action-adventure', 'Syndicate')
# (1993, 'Action-adventure', "The Legend of Zelda: Link's Awakening")
# (1993, 'Platform', 'Day of the Tentacle')
# (1993, 'Platform', 'Doom')
# (1993, 'Platform', 'Gunstar Heroes')
# (1993, 'Platform', 'Mega Man X')
# (1993, 'Platform', 'Mortal Kombat II')
# (1993, 'Platform', 'Myst')
# (1993, 'Platform', 'NBA Jam')
# (1993, 'Platform', 'Phantasy Star IV')
# (1993, 'Platform', 'Ridge Racer')
# (1993, 'Platform', 'Sam & Max Hit the Road')
# (1993, 'Platform', 'Samurai Shodown')
# (1993, 'Platform', 'Secret of Mana')
# (1993, 'Platform', 'SimCity 2000')
# (1993, 'Platform', 'Star Fox')
# (1993, 'Platform', 'Syndicate')
# (1993, 'Platform', "The Legend of Zelda: Link's Awakening")
# (1993, 'Fighting', 'Day of the Tentacle')
# (1993, 'Fighting', 'Doom')
# (1993, 'Fighting', 'Gunstar Heroes')
# (1993, 'Fighting', 'Mega Man X')
# (1993, 'Fighting', 'Mortal Kombat II')
# (1993, 'Fighting', 'Myst')
# (1993, 'Fighting', 'NBA Jam')
# (1993, 'Fighting', 'Phantasy Star IV')
# (1993, 'Fighting', 'Ridge Racer')
# (1993, 'Fighting', 'Sam & Max Hit the Road')
# (1993, 'Fighting', 'Samurai Shodown')
# (1993, 'Fighting', 'Secret of Mana')
# (1993, 'Fighting', 'SimCity 2000')
# (1993, 'Fighting', 'Star Fox')
# (1993, 'Fighting', 'Syndicate')
# (1993, 'Fighting', "The Legend of Zelda: Link's Awakening")
# (1993, 'Adventure', 'Day of the Tentacle')
# (1993, 'Adventure', 'Doom')
# (1993, 'Adventure', 'Gunstar Heroes')
# (1993, 'Adventure', 'Mega Man X')
# (1993, 'Adventure', 'Mortal Kombat II')
# (1993, 'Adventure', 'Myst')
# (1993, 'Adventure', 'NBA Jam')
# (1993, 'Adventure', 'Phantasy Star IV')
# (1993, 'Adventure', 'Ridge Racer')
# (1993, 'Adventure', 'Sam & Max Hit the Road')
# (1993, 'Adventure', 'Samurai Shodown')
# (1993, 'Adventure', 'Secret of Mana')
# (1993, 'Adventure', 'SimCity 2000')
# (1993, 'Adventure', 'Star Fox')
# (1993, 'Adventure', 'Syndicate')
# (1993, 'Adventure', "The Legend of Zelda: Link's Awakening")
# (1993, 'Sports', 'Day of the Tentacle')
# (1993, 'Sports', 'Doom')
# (1993, 'Sports', 'Gunstar Heroes')
# (1993, 'Sports', 'Mega Man X')
# (1993, 'Sports', 'Mortal Kombat II')
# (1993, 'Sports', 'Myst')
# (1993, 'Sports', 'NBA Jam')
# (1993, 'Sports', 'Phantasy Star IV')
# (1993, 'Sports', 'Ridge Racer')
# (1993, 'Sports', 'Sam & Max Hit the Road')
# (1993, 'Sports', 'Samurai Shodown')
# (1993, 'Sports', 'Secret of Mana')
# (1993, 'Sports', 'SimCity 2000')
# (1993, 'Sports', 'Star Fox')
# (1993, 'Sports', 'Syndicate')
# (1993, 'Sports', "The Legend of Zelda: Link's Awakening")
# (1993, 'Role-playing', 'Day of the Tentacle')
# (1993, 'Role-playing', 'Doom')
# (1993, 'Role-playing', 'Gunstar Heroes')
# (1993, 'Role-playing', 'Mega Man X')
# (1993, 'Role-playing', 'Mortal Kombat II')
# (1993, 'Role-playing', 'Myst')
# (1993, 'Role-playing', 'NBA Jam')
# (1993, 'Role-playing', 'Phantasy Star IV')
# (1993, 'Role-playing', 'Ridge Racer')
# (1993, 'Role-playing', 'Sam & Max Hit the Road')
# (1993, 'Role-playing', 'Samurai Shodown')
# (1993, 'Role-playing', 'Secret of Mana')
# (1993, 'Role-playing', 'SimCity 2000')
# (1993, 'Role-playing', 'Star Fox')
# (1993, 'Role-playing', 'Syndicate')
# (1993, 'Role-playing', "The Legend of Zelda: Link's Awakening")
# (1993, 'Racing', 'Day of the Tentacle')
# (1993, 'Racing', 'Doom')
# (1993, 'Racing', 'Gunstar Heroes')
# (1993, 'Racing', 'Mega Man X')
# (1993, 'Racing', 'Mortal Kombat II')
# (1993, 'Racing', 'Myst')
# (1993, 'Racing', 'NBA Jam')
# (1993, 'Racing', 'Phantasy Star IV')
# (1993, 'Racing', 'Ridge Racer')
# (1993, 'Racing', 'Sam & Max Hit the Road')
# (1993, 'Racing', 'Samurai Shodown')
# (1993, 'Racing', 'Secret of Mana')
# (1993, 'Racing', 'SimCity 2000')
# (1993, 'Racing', 'Star Fox')
# (1993, 'Racing', 'Syndicate')
# (1993, 'Racing', "The Legend of Zelda: Link's Awakening")
# (1993, 'Adventure', 'Day of the Tentacle')
# (1993, 'Adventure', 'Doom')
# (1993, 'Adventure', 'Gunstar Heroes')
# (1993, 'Adventure', 'Mega Man X')
# (1993, 'Adventure', 'Mortal Kombat II')
# (1993, 'Adventure', 'Myst')
# (1993, 'Adventure', 'NBA Jam')
# (1993, 'Adventure', 'Phantasy Star IV')
# (1993, 'Adventure', 'Ridge Racer')
# (1993, 'Adventure', 'Sam & Max Hit the Road')
# (1993, 'Adventure', 'Samurai Shodown')
# (1993, 'Adventure', 'Secret of Mana')
# (1993, 'Adventure', 'SimCity 2000')
# (1993, 'Adventure', 'Star Fox')
# (1993, 'Adventure', 'Syndicate')
# (1993, 'Adventure', "The Legend of Zelda: Link's Awakening")
# (1993, 'Action role-playing', 'Day of the Tentacle')
# (1993, 'Action role-playing', 'Doom')
# (1993, 'Action role-playing', 'Gunstar Heroes')
# (1993, 'Action role-playing', 'Mega Man X')
# (1993, 'Action role-playing', 'Mortal Kombat II')
# (1993, 'Action role-playing', 'Myst')
# (1993, 'Action role-playing', 'NBA Jam')
# (1993, 'Action role-playing', 'Phantasy Star IV')
# (1993, 'Action role-playing', 'Ridge Racer')
# (1993, 'Action role-playing', 'Sam & Max Hit the Road')
# (1993, 'Action role-playing', 'Samurai Shodown')
# (1993, 'Action role-playing', 'Secret of Mana')
# (1993, 'Action role-playing', 'SimCity 2000')
# (1993, 'Action role-playing', 'Star Fox')
# (1993, 'Action role-playing', 'Syndicate')
# (1993, 'Action role-playing', "The Legend of Zelda: Link's Awakening")
# (1993, 'Fighting', 'Day of the Tentacle')
# (1993, 'Fighting', 'Doom')
# (1993, 'Fighting', 'Gunstar Heroes')
# (1993, 'Fighting', 'Mega Man X')
# (1993, 'Fighting', 'Mortal Kombat II')
# (1993, 'Fighting', 'Myst')
# (1993, 'Fighting', 'NBA Jam')
# (1993, 'Fighting', 'Phantasy Star IV')
# (1993, 'Fighting', 'Ridge Racer')
# (1993, 'Fighting', 'Sam & Max Hit the Road')
# (1993, 'Fighting', 'Samurai Shodown')
# (1993, 'Fighting', 'Secret of Mana')
# (1993, 'Fighting', 'SimCity 2000')
# (1993, 'Fighting', 'Star Fox')
# (1993, 'Fighting', 'Syndicate')
# (1993, 'Fighting', "The Legend of Zelda: Link's Awakening")
# (1993, 'City-building', 'Day of the Tentacle')
# (1993, 'City-building', 'Doom')
# (1993, 'City-building', 'Gunstar Heroes')
# (1993, 'City-building', 'Mega Man X')
# (1993, 'City-building', 'Mortal Kombat II')
# (1993, 'City-building', 'Myst')
# (1993, 'City-building', 'NBA Jam')
# (1993, 'City-building', 'Phantasy Star IV')
# (1993, 'City-building', 'Ridge Racer')
# (1993, 'City-building', 'Sam & Max Hit the Road')
# (1993, 'City-building', 'Samurai Shodown')
# (1993, 'City-building', 'Secret of Mana')
# (1993, 'City-building', 'SimCity 2000')
# (1993, 'City-building', 'Star Fox')
# (1993, 'City-building', 'Syndicate')
# (1993, 'City-building', "The Legend of Zelda: Link's Awakening")
# (1993, 'Rail shooter', 'Day of the Tentacle')
# (1993, 'Rail shooter', 'Doom')
# (1993, 'Rail shooter', 'Gunstar Heroes')
# (1993, 'Rail shooter', 'Mega Man X')
# (1993, 'Rail shooter', 'Mortal Kombat II')
# (1993, 'Rail shooter', 'Myst')
# (1993, 'Rail shooter', 'NBA Jam')
# (1993, 'Rail shooter', 'Phantasy Star IV')
# (1993, 'Rail shooter', 'Ridge Racer')
# (1993, 'Rail shooter', 'Sam & Max Hit the Road')
# (1993, 'Rail shooter', 'Samurai Shodown')
# (1993, 'Rail shooter', 'Secret of Mana')
# (1993, 'Rail shooter', 'SimCity 2000')
# (1993, 'Rail shooter', 'Star Fox')
# (1993, 'Rail shooter', 'Syndicate')
# (1993, 'Rail shooter', "The Legend of Zelda: Link's Awakening")
# (1993, 'Real-time tactics', 'Day of the Tentacle')
# (1993, 'Real-time tactics', 'Doom')
# (1993, 'Real-time tactics', 'Gunstar Heroes')
# (1993, 'Real-time tactics', 'Mega Man X')
# (1993, 'Real-time tactics', 'Mortal Kombat II')
# (1993, 'Real-time tactics', 'Myst')
# (1993, 'Real-time tactics', 'NBA Jam')
# (1993, 'Real-time tactics', 'Phantasy Star IV')
# (1993, 'Real-time tactics', 'Ridge Racer')
# (1993, 'Real-time tactics', 'Sam & Max Hit the Road')
# (1993, 'Real-time tactics', 'Samurai Shodown')
# (1993, 'Real-time tactics', 'Secret of Mana')
# (1993, 'Real-time tactics', 'SimCity 2000')
# (1993, 'Real-time tactics', 'Star Fox')
# (1993, 'Real-time tactics', 'Syndicate')
# (1993, 'Real-time tactics', "The Legend of Zelda: Link's Awakening")
# (1994, 'Racing', 'Daytona USA')
# (1994, 'Racing', 'Donkey Kong Country')
# (1994, 'Racing', 'Doom II')
# (1994, 'Racing', 'EarthBound')
# (1994, 'Racing', 'Final Fantasy VI')
# (1994, 'Racing', 'Sega Rally Championship')
# (1994, 'Racing', 'Sensible World of Soccer')
# (1994, 'Racing', 'Star Wars: TIE Fighter')
# (1994, 'Racing', 'Super Metroid')
# (1994, 'Racing', 'Tempest 2000')
# (1994, 'Racing', 'Theme Park')
# (1994, 'Racing', 'Virtua Fighter 2')
# (1994, 'Racing', 'X-COM: UFO Defense')
# (1994, 'Platform', 'Daytona USA')
# (1994, 'Platform', 'Donkey Kong Country')
# (1994, 'Platform', 'Doom II')
# (1994, 'Platform', 'EarthBound')
# (1994, 'Platform', 'Final Fantasy VI')
# (1994, 'Platform', 'Sega Rally Championship')
# (1994, 'Platform', 'Sensible World of Soccer')
# (1994, 'Platform', 'Star Wars: TIE Fighter')
# (1994, 'Platform', 'Super Metroid')
# (1994, 'Platform', 'Tempest 2000')
# (1994, 'Platform', 'Theme Park')
# (1994, 'Platform', 'Virtua Fighter 2')
# (1994, 'Platform', 'X-COM: UFO Defense')
# (1994, 'First-person shooter', 'Daytona USA')
# (1994, 'First-person shooter', 'Donkey Kong Country')
# (1994, 'First-person shooter', 'Doom II')
# (1994, 'First-person shooter', 'EarthBound')
# (1994, 'First-person shooter', 'Final Fantasy VI')
# (1994, 'First-person shooter', 'Sega Rally Championship')
# (1994, 'First-person shooter', 'Sensible World of Soccer')
# (1994, 'First-person shooter', 'Star Wars: TIE Fighter')
# (1994, 'First-person shooter', 'Super Metroid')
# (1994, 'First-person shooter', 'Tempest 2000')
# (1994, 'First-person shooter', 'Theme Park')
# (1994, 'First-person shooter', 'Virtua Fighter 2')
# (1994, 'First-person shooter', 'X-COM: UFO Defense')
# (1994, 'Role-playing', 'Daytona USA')
# (1994, 'Role-playing', 'Donkey Kong Country')
# (1994, 'Role-playing', 'Doom II')
# (1994, 'Role-playing', 'EarthBound')
# (1994, 'Role-playing', 'Final Fantasy VI')
# (1994, 'Role-playing', 'Sega Rally Championship')
# (1994, 'Role-playing', 'Sensible World of Soccer')
# (1994, 'Role-playing', 'Star Wars: TIE Fighter')
# (1994, 'Role-playing', 'Super Metroid')
# (1994, 'Role-playing', 'Tempest 2000')
# (1994, 'Role-playing', 'Theme Park')
# (1994, 'Role-playing', 'Virtua Fighter 2')
# (1994, 'Role-playing', 'X-COM: UFO Defense')
# (1994, 'Role-playing', 'Daytona USA')
# (1994, 'Role-playing', 'Donkey Kong Country')
# (1994, 'Role-playing', 'Doom II')
# (1994, 'Role-playing', 'EarthBound')
# (1994, 'Role-playing', 'Final Fantasy VI')
# (1994, 'Role-playing', 'Sega Rally Championship')
# (1994, 'Role-playing', 'Sensible World of Soccer')
# (1994, 'Role-playing', 'Star Wars: TIE Fighter')
# (1994, 'Role-playing', 'Super Metroid')
# (1994, 'Role-playing', 'Tempest 2000')
# (1994, 'Role-playing', 'Theme Park')
# (1994, 'Role-playing', 'Virtua Fighter 2')
# (1994, 'Role-playing', 'X-COM: UFO Defense')
# (1994, 'Racing', 'Daytona USA')
# (1994, 'Racing', 'Donkey Kong Country')
# (1994, 'Racing', 'Doom II')
# (1994, 'Racing', 'EarthBound')
# (1994, 'Racing', 'Final Fantasy VI')
# (1994, 'Racing', 'Sega Rally Championship')
# (1994, 'Racing', 'Sensible World of Soccer')
# (1994, 'Racing', 'Star Wars: TIE Fighter')
# (1994, 'Racing', 'Super Metroid')
# (1994, 'Racing', 'Tempest 2000')
# (1994, 'Racing', 'Theme Park')
# (1994, 'Racing', 'Virtua Fighter 2')
# (1994, 'Racing', 'X-COM: UFO Defense')
# (1994, 'Sports', 'Daytona USA')
# (1994, 'Sports', 'Donkey Kong Country')
# (1994, 'Sports', 'Doom II')
# (1994, 'Sports', 'EarthBound')
# (1994, 'Sports', 'Final Fantasy VI')
# (1994, 'Sports', 'Sega Rally Championship')
# (1994, 'Sports', 'Sensible World of Soccer')
# (1994, 'Sports', 'Star Wars: TIE Fighter')
# (1994, 'Sports', 'Super Metroid')
# (1994, 'Sports', 'Tempest 2000')
# (1994, 'Sports', 'Theme Park')
# (1994, 'Sports', 'Virtua Fighter 2')
# (1994, 'Sports', 'X-COM: UFO Defense')
# (1994, 'Space flight simulator', 'Daytona USA')
# (1994, 'Space flight simulator', 'Donkey Kong Country')
# (1994, 'Space flight simulator', 'Doom II')
# (1994, 'Space flight simulator', 'EarthBound')
# (1994, 'Space flight simulator', 'Final Fantasy VI')
# (1994, 'Space flight simulator', 'Sega Rally Championship')
# (1994, 'Space flight simulator', 'Sensible World of Soccer')
# (1994, 'Space flight simulator', 'Star Wars: TIE Fighter')
# (1994, 'Space flight simulator', 'Super Metroid')
# (1994, 'Space flight simulator', 'Tempest 2000')
# (1994, 'Space flight simulator', 'Theme Park')
# (1994, 'Space flight simulator', 'Virtua Fighter 2')
# (1994, 'Space flight simulator', 'X-COM: UFO Defense')
# (1994, 'Action-adventure', 'Daytona USA')
# (1994, 'Action-adventure', 'Donkey Kong Country')
# (1994, 'Action-adventure', 'Doom II')
# (1994, 'Action-adventure', 'EarthBound')
# (1994, 'Action-adventure', 'Final Fantasy VI')
# (1994, 'Action-adventure', 'Sega Rally Championship')
# (1994, 'Action-adventure', 'Sensible World of Soccer')
# (1994, 'Action-adventure', 'Star Wars: TIE Fighter')
# (1994, 'Action-adventure', 'Super Metroid')
# (1994, 'Action-adventure', 'Tempest 2000')
# (1994, 'Action-adventure', 'Theme Park')
# (1994, 'Action-adventure', 'Virtua Fighter 2')
# (1994, 'Action-adventure', 'X-COM: UFO Defense')
# (1994, "Shoot 'em up", 'Daytona USA')
# (1994, "Shoot 'em up", 'Donkey Kong Country')
# (1994, "Shoot 'em up", 'Doom II')
# (1994, "Shoot 'em up", 'EarthBound')
# (1994, "Shoot 'em up", 'Final Fantasy VI')
# (1994, "Shoot 'em up", 'Sega Rally Championship')
# (1994, "Shoot 'em up", 'Sensible World of Soccer')
# (1994, "Shoot 'em up", 'Star Wars: TIE Fighter')
# (1994, "Shoot 'em up", 'Super Metroid')
# (1994, "Shoot 'em up", 'Tempest 2000')
# (1994, "Shoot 'em up", 'Theme Park')
# (1994, "Shoot 'em up", 'Virtua Fighter 2')
# (1994, "Shoot 'em up", 'X-COM: UFO Defense')
# (1994, 'Business simulation', 'Daytona USA')
# (1994, 'Business simulation', 'Donkey Kong Country')
# (1994, 'Business simulation', 'Doom II')
# (1994, 'Business simulation', 'EarthBound')
# (1994, 'Business simulation', 'Final Fantasy VI')
# (1994, 'Business simulation', 'Sega Rally Championship')
# (1994, 'Business simulation', 'Sensible World of Soccer')
# (1994, 'Business simulation', 'Star Wars: TIE Fighter')
# (1994, 'Business simulation', 'Super Metroid')
# (1994, 'Business simulation', 'Tempest 2000')
# (1994, 'Business simulation', 'Theme Park')
# (1994, 'Business simulation', 'Virtua Fighter 2')
# (1994, 'Business simulation', 'X-COM: UFO Defense')
# (1994, 'Fighting', 'Daytona USA')
# (1994, 'Fighting', 'Donkey Kong Country')
# (1994, 'Fighting', 'Doom II')
# (1994, 'Fighting', 'EarthBound')
# (1994, 'Fighting', 'Final Fantasy VI')
# (1994, 'Fighting', 'Sega Rally Championship')
# (1994, 'Fighting', 'Sensible World of Soccer')
# (1994, 'Fighting', 'Star Wars: TIE Fighter')
# (1994, 'Fighting', 'Super Metroid')
# (1994, 'Fighting', 'Tempest 2000')
# (1994, 'Fighting', 'Theme Park')
# (1994, 'Fighting', 'Virtua Fighter 2')
# (1994, 'Fighting', 'X-COM: UFO Defense')
# (1994, 'Turn-based strategy', 'Daytona USA')
# (1994, 'Turn-based strategy', 'Donkey Kong Country')
# (1994, 'Turn-based strategy', 'Doom II')
# (1994, 'Turn-based strategy', 'EarthBound')
# (1994, 'Turn-based strategy', 'Final Fantasy VI')
# (1994, 'Turn-based strategy', 'Sega Rally Championship')
# (1994, 'Turn-based strategy', 'Sensible World of Soccer')
# (1994, 'Turn-based strategy', 'Star Wars: TIE Fighter')
# (1994, 'Turn-based strategy', 'Super Metroid')
# (1994, 'Turn-based strategy', 'Tempest 2000')
# (1994, 'Turn-based strategy', 'Theme Park')
# (1994, 'Turn-based strategy', 'Virtua Fighter 2')
# (1994, 'Turn-based strategy', 'X-COM: UFO Defense')
# (1995, 'Role-playing', 'Chrono Trigger')
# (1995, 'Role-playing', 'Command & Conquer')
# (1995, 'Role-playing', 'MechWarrior 2: 31st Century Combat')
# (1995, 'Role-playing', 'Warcraft II: Tides of Darkness')
# (1995, 'Role-playing', 'Wipeout')
# (1995, 'Role-playing', 'Worms')
# (1995, 'Role-playing', "Yoshi's Island")
# (1995, 'Real-time strategy', 'Chrono Trigger')
# (1995, 'Real-time strategy', 'Command & Conquer')
# (1995, 'Real-time strategy', 'MechWarrior 2: 31st Century Combat')
# (1995, 'Real-time strategy', 'Warcraft II: Tides of Darkness')
# (1995, 'Real-time strategy', 'Wipeout')
# (1995, 'Real-time strategy', 'Worms')
# (1995, 'Real-time strategy', "Yoshi's Island")
# (1995, 'Vehicle simulation', 'Chrono Trigger')
# (1995, 'Vehicle simulation', 'Command & Conquer')
# (1995, 'Vehicle simulation', 'MechWarrior 2: 31st Century Combat')
# (1995, 'Vehicle simulation', 'Warcraft II: Tides of Darkness')
# (1995, 'Vehicle simulation', 'Wipeout')
# (1995, 'Vehicle simulation', 'Worms')
# (1995, 'Vehicle simulation', "Yoshi's Island")
# (1995, 'Real-time strategy', 'Chrono Trigger')
# (1995, 'Real-time strategy', 'Command & Conquer')
# (1995, 'Real-time strategy', 'MechWarrior 2: 31st Century Combat')
# (1995, 'Real-time strategy', 'Warcraft II: Tides of Darkness')
# (1995, 'Real-time strategy', 'Wipeout')
# (1995, 'Real-time strategy', 'Worms')
# (1995, 'Real-time strategy', "Yoshi's Island")
# (1995, 'Racing', 'Chrono Trigger')
# (1995, 'Racing', 'Command & Conquer')
# (1995, 'Racing', 'MechWarrior 2: 31st Century Combat')
# (1995, 'Racing', 'Warcraft II: Tides of Darkness')
# (1995, 'Racing', 'Wipeout')
# (1995, 'Racing', 'Worms')
# (1995, 'Racing', "Yoshi's Island")
# (1995, 'Artillery', 'Chrono Trigger')
# (1995, 'Artillery', 'Command & Conquer')
# (1995, 'Artillery', 'MechWarrior 2: 31st Century Combat')
# (1995, 'Artillery', 'Warcraft II: Tides of Darkness')
# (1995, 'Artillery', 'Wipeout')
# (1995, 'Artillery', 'Worms')
# (1995, 'Artillery', "Yoshi's Island")
# (1995, 'Platform', 'Chrono Trigger')
# (1995, 'Platform', 'Command & Conquer')
# (1995, 'Platform', 'MechWarrior 2: 31st Century Combat')
# (1995, 'Platform', 'Warcraft II: Tides of Darkness')
# (1995, 'Platform', 'Wipeout')
# (1995, 'Platform', 'Worms')
# (1995, 'Platform', "Yoshi's Island")
# (1996, 'Turn-based strategy', 'Civilization II')
# (1996, 'Turn-based strategy', 'Command & Conquer: Red Alert')
# (1996, 'Turn-based strategy', 'Duke Nukem 3D')
# (1996, 'Turn-based strategy', 'Mario Kart 64')
# (1996, 'Turn-based strategy', 'Nights into Dreams')
# (1996, 'Turn-based strategy', 'PaRappa the Rapper')
# (1996, 'Turn-based strategy', 'PokÃ©mon Red and Blue')
# (1996, 'Turn-based strategy', 'Quake')
# (1996, 'Turn-based strategy', 'Resident Evil')
# (1996, 'Turn-based strategy', 'Super Mario 64')
# (1996, 'Turn-based strategy', 'Tomb Raider')
# (1996, 'Turn-based strategy', 'Wave Race 64')
# (1996, 'Turn-based strategy', 'Wipeout 2097')
# (1996, 'Real-time strategy', 'Civilization II')
# (1996, 'Real-time strategy', 'Command & Conquer: Red Alert')
# (1996, 'Real-time strategy', 'Duke Nukem 3D')
# (1996, 'Real-time strategy', 'Mario Kart 64')
# (1996, 'Real-time strategy', 'Nights into Dreams')
# (1996, 'Real-time strategy', 'PaRappa the Rapper')
# (1996, 'Real-time strategy', 'PokÃ©mon Red and Blue')
# (1996, 'Real-time strategy', 'Quake')
# (1996, 'Real-time strategy', 'Resident Evil')
# (1996, 'Real-time strategy', 'Super Mario 64')
# (1996, 'Real-time strategy', 'Tomb Raider')
# (1996, 'Real-time strategy', 'Wave Race 64')
# (1996, 'Real-time strategy', 'Wipeout 2097')
# (1996, 'First-person shooter', 'Civilization II')
# (1996, 'First-person shooter', 'Command & Conquer: Red Alert')
# (1996, 'First-person shooter', 'Duke Nukem 3D')
# (1996, 'First-person shooter', 'Mario Kart 64')
# (1996, 'First-person shooter', 'Nights into Dreams')
# (1996, 'First-person shooter', 'PaRappa the Rapper')
# (1996, 'First-person shooter', 'PokÃ©mon Red and Blue')
# (1996, 'First-person shooter', 'Quake')
# (1996, 'First-person shooter', 'Resident Evil')
# (1996, 'First-person shooter', 'Super Mario 64')
# (1996, 'First-person shooter', 'Tomb Raider')
# (1996, 'First-person shooter', 'Wave Race 64')
# (1996, 'First-person shooter', 'Wipeout 2097')
# (1996, 'Kart racing', 'Civilization II')
# (1996, 'Kart racing', 'Command & Conquer: Red Alert')
# (1996, 'Kart racing', 'Duke Nukem 3D')
# (1996, 'Kart racing', 'Mario Kart 64')
# (1996, 'Kart racing', 'Nights into Dreams')
# (1996, 'Kart racing', 'PaRappa the Rapper')
# (1996, 'Kart racing', 'PokÃ©mon Red and Blue')
# (1996, 'Kart racing', 'Quake')
# (1996, 'Kart racing', 'Resident Evil')
# (1996, 'Kart racing', 'Super Mario 64')
# (1996, 'Kart racing', 'Tomb Raider')
# (1996, 'Kart racing', 'Wave Race 64')
# (1996, 'Kart racing', 'Wipeout 2097')
# (1996, 'Action', 'Civilization II')
# (1996, 'Action', 'Command & Conquer: Red Alert')
# (1996, 'Action', 'Duke Nukem 3D')
# (1996, 'Action', 'Mario Kart 64')
# (1996, 'Action', 'Nights into Dreams')
# (1996, 'Action', 'PaRappa the Rapper')
# (1996, 'Action', 'PokÃ©mon Red and Blue')
# (1996, 'Action', 'Quake')
# (1996, 'Action', 'Resident Evil')
# (1996, 'Action', 'Super Mario 64')
# (1996, 'Action', 'Tomb Raider')
# (1996, 'Action', 'Wave Race 64')
# (1996, 'Action', 'Wipeout 2097')
# (1996, 'Rhythm', 'Civilization II')
# (1996, 'Rhythm', 'Command & Conquer: Red Alert')
# (1996, 'Rhythm', 'Duke Nukem 3D')
# (1996, 'Rhythm', 'Mario Kart 64')
# (1996, 'Rhythm', 'Nights into Dreams')
# (1996, 'Rhythm', 'PaRappa the Rapper')
# (1996, 'Rhythm', 'PokÃ©mon Red and Blue')
# (1996, 'Rhythm', 'Quake')
# (1996, 'Rhythm', 'Resident Evil')
# (1996, 'Rhythm', 'Super Mario 64')
# (1996, 'Rhythm', 'Tomb Raider')
# (1996, 'Rhythm', 'Wave Race 64')
# (1996, 'Rhythm', 'Wipeout 2097')
# (1996, 'Role-playing', 'Civilization II')
# (1996, 'Role-playing', 'Command & Conquer: Red Alert')
# (1996, 'Role-playing', 'Duke Nukem 3D')
# (1996, 'Role-playing', 'Mario Kart 64')
# (1996, 'Role-playing', 'Nights into Dreams')
# (1996, 'Role-playing', 'PaRappa the Rapper')
# (1996, 'Role-playing', 'PokÃ©mon Red and Blue')
# (1996, 'Role-playing', 'Quake')
# (1996, 'Role-playing', 'Resident Evil')
# (1996, 'Role-playing', 'Super Mario 64')
# (1996, 'Role-playing', 'Tomb Raider')
# (1996, 'Role-playing', 'Wave Race 64')
# (1996, 'Role-playing', 'Wipeout 2097')
# (1996, 'First-person shooter', 'Civilization II')
# (1996, 'First-person shooter', 'Command & Conquer: Red Alert')
# (1996, 'First-person shooter', 'Duke Nukem 3D')
# (1996, 'First-person shooter', 'Mario Kart 64')
# (1996, 'First-person shooter', 'Nights into Dreams')
# (1996, 'First-person shooter', 'PaRappa the Rapper')
# (1996, 'First-person shooter', 'PokÃ©mon Red and Blue')
# (1996, 'First-person shooter', 'Quake')
# (1996, 'First-person shooter', 'Resident Evil')
# (1996, 'First-person shooter', 'Super Mario 64')
# (1996, 'First-person shooter', 'Tomb Raider')
# (1996, 'First-person shooter', 'Wave Race 64')
# (1996, 'First-person shooter', 'Wipeout 2097')
# (1996, 'Survival horror', 'Civilization II')
# (1996, 'Survival horror', 'Command & Conquer: Red Alert')
# (1996, 'Survival horror', 'Duke Nukem 3D')
# (1996, 'Survival horror', 'Mario Kart 64')
# (1996, 'Survival horror', 'Nights into Dreams')
# (1996, 'Survival horror', 'PaRappa the Rapper')
# (1996, 'Survival horror', 'PokÃ©mon Red and Blue')
# (1996, 'Survival horror', 'Quake')
# (1996, 'Survival horror', 'Resident Evil')
# (1996, 'Survival horror', 'Super Mario 64')
# (1996, 'Survival horror', 'Tomb Raider')
# (1996, 'Survival horror', 'Wave Race 64')
# (1996, 'Survival horror', 'Wipeout 2097')
# (1996, 'Platform', 'Civilization II')
# (1996, 'Platform', 'Command & Conquer: Red Alert')
# (1996, 'Platform', 'Duke Nukem 3D')
# (1996, 'Platform', 'Mario Kart 64')
# (1996, 'Platform', 'Nights into Dreams')
# (1996, 'Platform', 'PaRappa the Rapper')
# (1996, 'Platform', 'PokÃ©mon Red and Blue')
# (1996, 'Platform', 'Quake')
# (1996, 'Platform', 'Resident Evil')
# (1996, 'Platform', 'Super Mario 64')
# (1996, 'Platform', 'Tomb Raider')
# (1996, 'Platform', 'Wave Race 64')
# (1996, 'Platform', 'Wipeout 2097')
# (1996, 'Action-adventure', 'Civilization II')
# (1996, 'Action-adventure', 'Command & Conquer: Red Alert')
# (1996, 'Action-adventure', 'Duke Nukem 3D')
# (1996, 'Action-adventure', 'Mario Kart 64')
# (1996, 'Action-adventure', 'Nights into Dreams')
# (1996, 'Action-adventure', 'PaRappa the Rapper')
# (1996, 'Action-adventure', 'PokÃ©mon Red and Blue')
# (1996, 'Action-adventure', 'Quake')
# (1996, 'Action-adventure', 'Resident Evil')
# (1996, 'Action-adventure', 'Super Mario 64')
# (1996, 'Action-adventure', 'Tomb Raider')
# (1996, 'Action-adventure', 'Wave Race 64')
# (1996, 'Action-adventure', 'Wipeout 2097')
# (1996, 'Racing', 'Civilization II')
# (1996, 'Racing', 'Command & Conquer: Red Alert')
# ...
# (2008, 'Tactical role-playing', 'Street Fighter IV')
# (2008, 'Tactical role-playing', 'Super Smash Bros. Brawl')
# (2008, 'Tactical role-playing', 'Valkyria Chronicles')
# (2009, 'Puzzle', 'Angry Birds')
# (2009, 'Puzzle', "Assassin's Creed II")
# (2009, 'Puzzle', 'Batman: Arkham Asylum')
# (2009, 'Puzzle', 'Bayonetta')
# (2009, 'Puzzle', 'Borderlands')
# (2009, 'Puzzle', "Demon's Souls")
# (2009, 'Puzzle', 'Dragon Age: Origins')
# (2009, 'Puzzle', 'League of Legends')
# (2009, 'Puzzle', 'Left 4 Dead 2')
# (2009, 'Puzzle', 'Plants vs. Zombies')
# (2009, 'Puzzle', 'Uncharted 2: Among Thieves')
# (2009, 'Action-adventure', 'Angry Birds')
# (2009, 'Action-adventure', "Assassin's Creed II")
# (2009, 'Action-adventure', 'Batman: Arkham Asylum')
# (2009, 'Action-adventure', 'Bayonetta')
# (2009, 'Action-adventure', 'Borderlands')
# (2009, 'Action-adventure', "Demon's Souls")
# (2009, 'Action-adventure', 'Dragon Age: Origins')
# (2009, 'Action-adventure', 'League of Legends')
# (2009, 'Action-adventure', 'Left 4 Dead 2')
# (2009, 'Action-adventure', 'Plants vs. Zombies')
# (2009, 'Action-adventure', 'Uncharted 2: Among Thieves')
# (2009, 'Action-adventure', 'Angry Birds')
# (2009, 'Action-adventure', "Assassin's Creed II")
# (2009, 'Action-adventure', 'Batman: Arkham Asylum')
# (2009, 'Action-adventure', 'Bayonetta')
# (2009, 'Action-adventure', 'Borderlands')
# (2009, 'Action-adventure', "Demon's Souls")
# (2009, 'Action-adventure', 'Dragon Age: Origins')
# (2009, 'Action-adventure', 'League of Legends')
# (2009, 'Action-adventure', 'Left 4 Dead 2')
# (2009, 'Action-adventure', 'Plants vs. Zombies')
# (2009, 'Action-adventure', 'Uncharted 2: Among Thieves')
# (2009, 'Action-adventure', 'Angry Birds')
# (2009, 'Action-adventure', "Assassin's Creed II")
# (2009, 'Action-adventure', 'Batman: Arkham Asylum')
# (2009, 'Action-adventure', 'Bayonetta')
# (2009, 'Action-adventure', 'Borderlands')
# (2009, 'Action-adventure', "Demon's Souls")
# (2009, 'Action-adventure', 'Dragon Age: Origins')
# (2009, 'Action-adventure', 'League of Legends')
# (2009, 'Action-adventure', 'Left 4 Dead 2')
# (2009, 'Action-adventure', 'Plants vs. Zombies')
# (2009, 'Action-adventure', 'Uncharted 2: Among Thieves')
# (2009, 'Action role-playing', 'Angry Birds')
# (2009, 'Action role-playing', "Assassin's Creed II")
# (2009, 'Action role-playing', 'Batman: Arkham Asylum')
# (2009, 'Action role-playing', 'Bayonetta')
# (2009, 'Action role-playing', 'Borderlands')
# (2009, 'Action role-playing', "Demon's Souls")
# (2009, 'Action role-playing', 'Dragon Age: Origins')
# (2009, 'Action role-playing', 'League of Legends')
# (2009, 'Action role-playing', 'Left 4 Dead 2')
# (2009, 'Action role-playing', 'Plants vs. Zombies')
# (2009, 'Action role-playing', 'Uncharted 2: Among Thieves')
# (2009, 'Action role-playing', 'Angry Birds')
# (2009, 'Action role-playing', "Assassin's Creed II")
# (2009, 'Action role-playing', 'Batman: Arkham Asylum')
# (2009, 'Action role-playing', 'Bayonetta')
# (2009, 'Action role-playing', 'Borderlands')
# (2009, 'Action role-playing', "Demon's Souls")
# (2009, 'Action role-playing', 'Dragon Age: Origins')
# (2009, 'Action role-playing', 'League of Legends')
# (2009, 'Action role-playing', 'Left 4 Dead 2')
# (2009, 'Action role-playing', 'Plants vs. Zombies')
# (2009, 'Action role-playing', 'Uncharted 2: Among Thieves')
# (2009, 'Role-playing', 'Angry Birds')
# (2009, 'Role-playing', "Assassin's Creed II")
# (2009, 'Role-playing', 'Batman: Arkham Asylum')
# (2009, 'Role-playing', 'Bayonetta')
# (2009, 'Role-playing', 'Borderlands')
# (2009, 'Role-playing', "Demon's Souls")
# (2009, 'Role-playing', 'Dragon Age: Origins')
# (2009, 'Role-playing', 'League of Legends')
# (2009, 'Role-playing', 'Left 4 Dead 2')
# (2009, 'Role-playing', 'Plants vs. Zombies')
# (2009, 'Role-playing', 'Uncharted 2: Among Thieves')
# (2009, 'MOBA', 'Angry Birds')
# (2009, 'MOBA', "Assassin's Creed II")
# (2009, 'MOBA', 'Batman: Arkham Asylum')
# (2009, 'MOBA', 'Bayonetta')
# (2009, 'MOBA', 'Borderlands')
# (2009, 'MOBA', "Demon's Souls")
# (2009, 'MOBA', 'Dragon Age: Origins')
# (2009, 'MOBA', 'League of Legends')
# (2009, 'MOBA', 'Left 4 Dead 2')
# (2009, 'MOBA', 'Plants vs. Zombies')
# (2009, 'MOBA', 'Uncharted 2: Among Thieves')
# (2009, 'First-person shooter', 'Angry Birds')
# (2009, 'First-person shooter', "Assassin's Creed II")
# (2009, 'First-person shooter', 'Batman: Arkham Asylum')
# (2009, 'First-person shooter', 'Bayonetta')
# (2009, 'First-person shooter', 'Borderlands')
# (2009, 'First-person shooter', "Demon's Souls")
# (2009, 'First-person shooter', 'Dragon Age: Origins')
# (2009, 'First-person shooter', 'League of Legends')
# (2009, 'First-person shooter', 'Left 4 Dead 2')
# (2009, 'First-person shooter', 'Plants vs. Zombies')
# (2009, 'First-person shooter', 'Uncharted 2: Among Thieves')
# (2009, 'Tower defense', 'Angry Birds')
# (2009, 'Tower defense', "Assassin's Creed II")
# (2009, 'Tower defense', 'Batman: Arkham Asylum')
# (2009, 'Tower defense', 'Bayonetta')
# (2009, 'Tower defense', 'Borderlands')
# (2009, 'Tower defense', "Demon's Souls")
# (2009, 'Tower defense', 'Dragon Age: Origins')
# (2009, 'Tower defense', 'League of Legends')
# (2009, 'Tower defense', 'Left 4 Dead 2')
# (2009, 'Tower defense', 'Plants vs. Zombies')
# (2009, 'Tower defense', 'Uncharted 2: Among Thieves')
# (2009, 'Action-adventure', 'Angry Birds')
# (2009, 'Action-adventure', "Assassin's Creed II")
# (2009, 'Action-adventure', 'Batman: Arkham Asylum')
# (2009, 'Action-adventure', 'Bayonetta')
# (2009, 'Action-adventure', 'Borderlands')
# (2009, 'Action-adventure', "Demon's Souls")
# (2009, 'Action-adventure', 'Dragon Age: Origins')
# (2009, 'Action-adventure', 'League of Legends')
# (2009, 'Action-adventure', 'Left 4 Dead 2')
# (2009, 'Action-adventure', 'Plants vs. Zombies')
# (2009, 'Action-adventure', 'Uncharted 2: Among Thieves')
# (2010, 'Turn-based strategy', 'Civilization V')
# (2010, 'Turn-based strategy', 'God of War III')
# (2010, 'Turn-based strategy', 'Heavy Rain')
# (2010, 'Turn-based strategy', 'Limbo')
# (2010, 'Turn-based strategy', 'Mass Effect 2')
# (2010, 'Turn-based strategy', 'Red Dead Redemption')
# (2010, 'Turn-based strategy', 'Rock Band 3')
# (2010, 'Turn-based strategy', 'StarCraft II: Wings of Liberty')
# (2010, 'Turn-based strategy', 'Super Mario Galaxy 2')
# (2010, 'Turn-based strategy', 'Super Meat Boy')
# (2010, 'Turn-based strategy', 'Xenoblade Chronicles')
# (2010, 'Action-adventure', 'Civilization V')
# (2010, 'Action-adventure', 'God of War III')
# (2010, 'Action-adventure', 'Heavy Rain')
# (2010, 'Action-adventure', 'Limbo')
# (2010, 'Action-adventure', 'Mass Effect 2')
# (2010, 'Action-adventure', 'Red Dead Redemption')
# (2010, 'Action-adventure', 'Rock Band 3')
# (2010, 'Action-adventure', 'StarCraft II: Wings of Liberty')
# (2010, 'Action-adventure', 'Super Mario Galaxy 2')
# (2010, 'Action-adventure', 'Super Meat Boy')
# (2010, 'Action-adventure', 'Xenoblade Chronicles')
# (2010, 'Adventure', 'Civilization V')
# (2010, 'Adventure', 'God of War III')
# (2010, 'Adventure', 'Heavy Rain')
# (2010, 'Adventure', 'Limbo')
# (2010, 'Adventure', 'Mass Effect 2')
# (2010, 'Adventure', 'Red Dead Redemption')
# (2010, 'Adventure', 'Rock Band 3')
# (2010, 'Adventure', 'StarCraft II: Wings of Liberty')
# (2010, 'Adventure', 'Super Mario Galaxy 2')
# (2010, 'Adventure', 'Super Meat Boy')
# (2010, 'Adventure', 'Xenoblade Chronicles')
# (2010, 'Puzzle-platformer', 'Civilization V')
# (2010, 'Puzzle-platformer', 'God of War III')
# (2010, 'Puzzle-platformer', 'Heavy Rain')
# (2010, 'Puzzle-platformer', 'Limbo')
# (2010, 'Puzzle-platformer', 'Mass Effect 2')
# (2010, 'Puzzle-platformer', 'Red Dead Redemption')
# (2010, 'Puzzle-platformer', 'Rock Band 3')
# (2010, 'Puzzle-platformer', 'StarCraft II: Wings of Liberty')
# (2010, 'Puzzle-platformer', 'Super Mario Galaxy 2')
# (2010, 'Puzzle-platformer', 'Super Meat Boy')
# (2010, 'Puzzle-platformer', 'Xenoblade Chronicles')
# (2010, 'Action role-playing', 'Civilization V')
# (2010, 'Action role-playing', 'God of War III')
# (2010, 'Action role-playing', 'Heavy Rain')
# (2010, 'Action role-playing', 'Limbo')
# (2010, 'Action role-playing', 'Mass Effect 2')
# (2010, 'Action role-playing', 'Red Dead Redemption')
# (2010, 'Action role-playing', 'Rock Band 3')
# (2010, 'Action role-playing', 'StarCraft II: Wings of Liberty')
# (2010, 'Action role-playing', 'Super Mario Galaxy 2')
# (2010, 'Action role-playing', 'Super Meat Boy')
# (2010, 'Action role-playing', 'Xenoblade Chronicles')
# (2010, 'Action-adventure', 'Civilization V')
# (2010, 'Action-adventure', 'God of War III')
# (2010, 'Action-adventure', 'Heavy Rain')
# (2010, 'Action-adventure', 'Limbo')
# (2010, 'Action-adventure', 'Mass Effect 2')
# (2010, 'Action-adventure', 'Red Dead Redemption')
# (2010, 'Action-adventure', 'Rock Band 3')
# (2010, 'Action-adventure', 'StarCraft II: Wings of Liberty')
# (2010, 'Action-adventure', 'Super Mario Galaxy 2')
# (2010, 'Action-adventure', 'Super Meat Boy')
# (2010, 'Action-adventure', 'Xenoblade Chronicles')
# (2010, 'Rhythm', 'Civilization V')
# (2010, 'Rhythm', 'God of War III')
# (2010, 'Rhythm', 'Heavy Rain')
# (2010, 'Rhythm', 'Limbo')
# (2010, 'Rhythm', 'Mass Effect 2')
# (2010, 'Rhythm', 'Red Dead Redemption')
# (2010, 'Rhythm', 'Rock Band 3')
# (2010, 'Rhythm', 'StarCraft II: Wings of Liberty')
# (2010, 'Rhythm', 'Super Mario Galaxy 2')
# (2010, 'Rhythm', 'Super Meat Boy')
# (2010, 'Rhythm', 'Xenoblade Chronicles')
# (2010, 'Real-time strategy', 'Civilization V')
# (2010, 'Real-time strategy', 'God of War III')
# (2010, 'Real-time strategy', 'Heavy Rain')
# (2010, 'Real-time strategy', 'Limbo')
# (2010, 'Real-time strategy', 'Mass Effect 2')
# (2010, 'Real-time strategy', 'Red Dead Redemption')
# (2010, 'Real-time strategy', 'Rock Band 3')
# (2010, 'Real-time strategy', 'StarCraft II: Wings of Liberty')
# (2010, 'Real-time strategy', 'Super Mario Galaxy 2')
# (2010, 'Real-time strategy', 'Super Meat Boy')
# (2010, 'Real-time strategy', 'Xenoblade Chronicles')
# (2010, 'Platform', 'Civilization V')
# (2010, 'Platform', 'God of War III')
# (2010, 'Platform', 'Heavy Rain')
# (2010, 'Platform', 'Limbo')
# (2010, 'Platform', 'Mass Effect 2')
# (2010, 'Platform', 'Red Dead Redemption')
# (2010, 'Platform', 'Rock Band 3')
# (2010, 'Platform', 'StarCraft II: Wings of Liberty')
# (2010, 'Platform', 'Super Mario Galaxy 2')
# (2010, 'Platform', 'Super Meat Boy')
# (2010, 'Platform', 'Xenoblade Chronicles')
# (2010, 'Platform', 'Civilization V')
# (2010, 'Platform', 'God of War III')
# (2010, 'Platform', 'Heavy Rain')
# (2010, 'Platform', 'Limbo')
# (2010, 'Platform', 'Mass Effect 2')
# (2010, 'Platform', 'Red Dead Redemption')
# (2010, 'Platform', 'Rock Band 3')
# (2010, 'Platform', 'StarCraft II: Wings of Liberty')
# (2010, 'Platform', 'Super Mario Galaxy 2')
# (2010, 'Platform', 'Super Meat Boy')
# (2010, 'Platform', 'Xenoblade Chronicles')
# (2010, 'Action role-playing', 'Civilization V')
# (2010, 'Action role-playing', 'God of War III')
# (2010, 'Action role-playing', 'Heavy Rain')
# (2010, 'Action role-playing', 'Limbo')
# (2010, 'Action role-playing', 'Mass Effect 2')
# (2010, 'Action role-playing', 'Red Dead Redemption')
# (2010, 'Action role-playing', 'Rock Band 3')
# (2010, 'Action role-playing', 'StarCraft II: Wings of Liberty')
# (2010, 'Action role-playing', 'Super Mario Galaxy 2')
# (2010, 'Action role-playing', 'Super Meat Boy')
# (2010, 'Action role-playing', 'Xenoblade Chronicles')
# (2011, 'Action-adventure', 'Batman: Arkham City')
# (2011, 'Action-adventure', 'Dark Souls')
# (2011, 'Action-adventure', 'Minecraft')
# (2011, 'Action-adventure', 'Portal 2')
# (2011, 'Action-adventure', 'The Elder Scrolls V: Skyrim')
# (2011, 'Action role-playing', 'Batman: Arkham City')
# (2011, 'Action role-playing', 'Dark Souls')
# (2011, 'Action role-playing', 'Minecraft')
# (2011, 'Action role-playing', 'Portal 2')
# (2011, 'Action role-playing', 'The Elder Scrolls V: Skyrim')
# (2011, 'Action role-playing', 'Batman: Arkham City')
# (2011, 'Action role-playing', 'Dark Souls')
# (2011, 'Action role-playing', 'Minecraft')
# (2011, 'Action role-playing', 'Portal 2')
# (2011, 'Action role-playing', 'The Elder Scrolls V: Skyrim')
# (2011, 'Sandbox', 'Batman: Arkham City')
# (2011, 'Sandbox', 'Dark Souls')
# (2011, 'Sandbox', 'Minecraft')
# (2011, 'Sandbox', 'Portal 2')
# (2011, 'Sandbox', 'The Elder Scrolls V: Skyrim')
# (2011, 'Puzzle-platformer', 'Batman: Arkham City')
# (2011, 'Puzzle-platformer', 'Dark Souls')
# (2011, 'Puzzle-platformer', 'Minecraft')
# (2011, 'Puzzle-platformer', 'Portal 2')
# (2011, 'Puzzle-platformer', 'The Elder Scrolls V: Skyrim')
# (2012, 'Action role-playing', 'Borderlands 2')
# (2012, 'Action role-playing', 'Dishonored')
# (2012, 'Action role-playing', 'Far Cry 3')
# (2012, 'Action role-playing', 'Fire Emblem Awakening')
# (2012, 'Action role-playing', 'Hotline Miami')
# (2012, 'Action role-playing', 'Journey')
# (2012, 'Action role-playing', 'The Walking Dead')
# (2012, 'Action role-playing', 'XCOM: Enemy Unknown')
# (2012, 'Stealth', 'Borderlands 2')
# (2012, 'Stealth', 'Dishonored')
# (2012, 'Stealth', 'Far Cry 3')
# (2012, 'Stealth', 'Fire Emblem Awakening')
# (2012, 'Stealth', 'Hotline Miami')
# (2012, 'Stealth', 'Journey')
# (2012, 'Stealth', 'The Walking Dead')
# (2012, 'Stealth', 'XCOM: Enemy Unknown')
# (2012, 'First-person shooter', 'Borderlands 2')
# (2012, 'First-person shooter', 'Dishonored')
# (2012, 'First-person shooter', 'Far Cry 3')
# (2012, 'First-person shooter', 'Fire Emblem Awakening')
# (2012, 'First-person shooter', 'Hotline Miami')
# (2012, 'First-person shooter', 'Journey')
# (2012, 'First-person shooter', 'The Walking Dead')
# (2012, 'First-person shooter', 'XCOM: Enemy Unknown')
# (2012, 'Tactical role-playing', 'Borderlands 2')
# (2012, 'Tactical role-playing', 'Dishonored')
# (2012, 'Tactical role-playing', 'Far Cry 3')
# (2012, 'Tactical role-playing', 'Fire Emblem Awakening')
# (2012, 'Tactical role-playing', 'Hotline Miami')
# (2012, 'Tactical role-playing', 'Journey')
# (2012, 'Tactical role-playing', 'The Walking Dead')
# (2012, 'Tactical role-playing', 'XCOM: Enemy Unknown')
# (2012, 'Top-down shooter', 'Borderlands 2')
# (2012, 'Top-down shooter', 'Dishonored')
# (2012, 'Top-down shooter', 'Far Cry 3')
# (2012, 'Top-down shooter', 'Fire Emblem Awakening')
# (2012, 'Top-down shooter', 'Hotline Miami')
# (2012, 'Top-down shooter', 'Journey')
# (2012, 'Top-down shooter', 'The Walking Dead')
# (2012, 'Top-down shooter', 'XCOM: Enemy Unknown')
# (2012, 'Adventure', 'Borderlands 2')
# (2012, 'Adventure', 'Dishonored')
# (2012, 'Adventure', 'Far Cry 3')
# (2012, 'Adventure', 'Fire Emblem Awakening')
# (2012, 'Adventure', 'Hotline Miami')
# (2012, 'Adventure', 'Journey')
# (2012, 'Adventure', 'The Walking Dead')
# (2012, 'Adventure', 'XCOM: Enemy Unknown')
# (2012, 'Adventure', 'Borderlands 2')
# (2012, 'Adventure', 'Dishonored')
# (2012, 'Adventure', 'Far Cry 3')
# (2012, 'Adventure', 'Fire Emblem Awakening')
# (2012, 'Adventure', 'Hotline Miami')
# (2012, 'Adventure', 'Journey')
# (2012, 'Adventure', 'The Walking Dead')
# (2012, 'Adventure', 'XCOM: Enemy Unknown')
# (2012, 'Turn-based strategy', 'Borderlands 2')
# (2012, 'Turn-based strategy', 'Dishonored')
# (2012, 'Turn-based strategy', 'Far Cry 3')
# (2012, 'Turn-based strategy', 'Fire Emblem Awakening')
# (2012, 'Turn-based strategy', 'Hotline Miami')
# (2012, 'Turn-based strategy', 'Journey')
# (2012, 'Turn-based strategy', 'The Walking Dead')
# (2012, 'Turn-based strategy', 'XCOM: Enemy Unknown')
# (2013, 'First-person shooter', 'BioShock Infinite')
# (2013, 'First-person shooter', 'Dota 2')
# (2013, 'MOBA', 'BioShock Infinite')
# (2013, 'MOBA', 'Dota 2')
#
# Количество игр по жанрам:
# ('Action', 7)
# ('Action role-playing', 20)
# ('Action-adventure', 36)
# ('Adventure', 12)
# ('Artillery', 1)
# ("Beat 'em up", 3)
# ('Block breaker', 1)
# ('Business simulation', 2)
# ('City-building', 2)
# ('Fighting', 12)
# ('First-person shooter', 26)
# ('God game', 1)
# ('Hack and slash', 1)
# ('Kart racing', 2)
# ('Life simulation', 3)
# ('MMORPG', 3)
# ('MOBA', 2)
# ('Maze', 2)
# ('Platform', 27)
# ('Puzzle', 4)
# ('Puzzle-platformer', 4)
# ('Racing', 15)
# ('Rail shooter', 4)
# ('Real-time strategy', 12)
# ('Real-time tactics', 1)
# ('Rhythm', 6)
# ('Role-playing', 24)
# ('Run and gun', 3)
# ('Sandbox', 1)
# ("Shoot 'em up", 10)
# ('Space flight simulator', 3)
# ('Sports', 9)
# ('Stealth', 10)
# ('Strategy', 3)
# ('Survival horror', 8)
# ('Tactical role-playing', 3)
# ('Third-person shooter', 4)
# ('Top-down shooter', 3)
# ('Tower defense', 1)
# ('Turn-based strategy', 7)
# ('Vehicle simulation', 2)
